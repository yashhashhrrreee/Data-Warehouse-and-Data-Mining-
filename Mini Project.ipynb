# %% [markdown]
# # DWDM CIE-3 Mini- Project
# Group members:
#  - 02 Yashashree Bedmutha
#  - 05 Yojana Naik
#  - 21 Jayraj Khivensara
#  - 26 Nayan Chaudhari

# %%
# Importing the Required Libraries
import nltk
nltk.download('stopwords')
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from textblob import TextBlob
from nltk.corpus import stopwords
from collections import Counter
import warnings; warnings.simplefilter('ignore')
import re
import string
from string import punctuation
from nltk import ngrams
from nltk.tokenize import word_tokenize 
from nltk.stem import SnowballStemmer

from sklearn.preprocessing import LabelEncoder
from xgboost import XGBClassifier
from lightgbm import LGBMModel,LGBMClassifier, plot_importance
from catboost import CatBoostClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.model_selection import train_test_split

stop_words = set(stopwords.words('english'))
punctuation = punctuation + '""“”’' + '∞θ÷α•à−β∅³π‘₹´°£€\×™√²—–&'
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Importing the datasets

df_train = pd.read_csv("drugsComTrain_raw.csv")
df_test = pd.read_csv("drugsComTest_raw.csv") 

print ("The shape of the train set given is : ", df_train.shape)
print ("The shape of the test set given is : ", df_test.shape)

df_train.head()
# Out:
# The shape of the train set given is :  (161297, 7)
# The shape of the test set given is :  (53766, 7)
#    uniqueID                  drugName                     condition  \
# 0    206461                 Valsartan  Left Ventricular Dysfunction
# 1     95260                Guanfacine                          ADHD
# 2     92703                    Lybrel                 Birth Control
# 3    138000                Ortho Evra                 Birth Control
# 4     35696  Buprenorphine / naloxone             Opiate Dependence
#
#                                               review  rating       date  \
# 0  "It has no side effect, I take it in combinati...       9  20-May-12
# 1  "My son is halfway through his fourth week of ...       8  27-Apr-10
# 2  "I used to take another oral contraceptive, wh...       5  14-Dec-09
# 3  "This is my first time using any form of birth...       8   3-Nov-15
# 4  "Suboxone has completely turned my life around...       9  27-Nov-16
#
#    usefulCount
# 0           27
# 1          192
# 2           17
# 3           10
# 4           37

# %%
# Data types
df_train.dtypes
# Out:
# uniqueID        int64
# drugName       object
# condition      object
# review         object
# rating          int64
# date           object
# usefulCount     int64
# dtype: object

# %% [markdown]
# We will merge both the datasets and do the preprocessing and exploratory data analysis for the whole dataset and after that, we will split the dataset later for training and testing

# %%
# Merging the test and train data 
merge = [df_train, df_test]
df_data = pd.concat(merge)

print (df_data.shape)

df_data.head(10)
# Out:
# (215063, 7)
#    uniqueID                            drugName                     condition  \
# 0    206461                           Valsartan  Left Ventricular Dysfunction
# 1     95260                          Guanfacine                          ADHD
# 2     92703                              Lybrel                 Birth Control
# 3    138000                          Ortho Evra                 Birth Control
# 4     35696            Buprenorphine / naloxone             Opiate Dependence
# 5    155963                              Cialis  Benign Prostatic Hyperplasia
# 6    165907                      Levonorgestrel       Emergency Contraception
# 7    102654                        Aripiprazole               Bipolar Disorde
# 8     74811                              Keppra                      Epilepsy
# 9     48928  Ethinyl estradiol / levonorgestrel                 Birth Control
#
#                                               review  rating       date  \
# 0  "It has no side effect, I take it in combinati...       9  20-May-12
# 1  "My son is halfway through his fourth week of ...       8  27-Apr-10
# 2  "I used to take another oral contraceptive, wh...       5  14-Dec-09
# 3  "This is my first time using any form of birth...       8   3-Nov-15
# 4  "Suboxone has completely turned my life around...       9  27-Nov-16
# 5  "2nd day on 5mg started to work with rock hard...       2  28-Nov-15
# 6  "He pulled out, but he cummed a bit in me. I t...       1   7-Mar-17
# 7  "Abilify changed my life. There is hope. I was...      10  14-Mar-15
# 8  " I Ve had  nothing but problems with the Kepp...       1   9-Aug-16
# 9  "I had been on the pill for many years. When m...       8   8-Dec-16
#
#    usefulCount
# 0           27
# 1          192
# 2           17
# 3           10
# 4           37
# 5           43
# 6            5
# 7           32
# 8           11
# 9            1

# %%
df_data.describe()
# Out:
#             uniqueID         rating    usefulCount
# count  215063.000000  215063.000000  215063.000000
# mean   116039.364814       6.990008      28.001004
# std     67007.913366       3.275554      36.346069
# min         0.000000       1.000000       0.000000
# 25%     58115.500000       5.000000       6.000000
# 50%    115867.000000       8.000000      16.000000
# 75%    173963.500000      10.000000      36.000000
# max    232291.000000      10.000000    1291.000000

# %%
# Null values
print ("Null values in the dataset : ", df_data.isnull().sum(axis = 0))
# Out:
# Null values in the dataset :  uniqueID          0
# drugName          0
# condition      1194
# review            0
# rating            0
# date              0
# usefulCount       0
# dtype: int64

# %%
# Calculating what percentage of data is null
size = df_data.shape[0]

print ("Total Size of the dataset : ", size)

total_na = df_data.isnull().sum(axis = 0)['condition']
print ("Null values : ", total_na)

print ("PERCENTAGE : ", (total_na/size)*100)
# Out:
# Total Size of the dataset :  215063
# Null values :  1194
# PERCENTAGE :  0.5551861547546533

# %%
# Dropping the data points with null values as it's very much less than 5% of the whole dataset
df_data = df_data.dropna(how = 'any', axis = 0)

print ("The shape of the dataset after null values removal :", df_data.shape)
# Out:
# The shape of the dataset after null values removal : (213869, 7)

# %%
# lowercasing the column names so it will be easier for access ^^
df_data.columns = df_data.columns.str.lower()

# %%
# Sorting the dataframe
df_data.sort_values(['uniqueid'], ascending = True, inplace = True)
df_data.reset_index(drop = True, inplace = True)
df_data.head(10)
# Out:
#    uniqueid             drugname                  condition  \
# 0         0  Medroxyprogesterone  Abnormal Uterine Bleeding
# 1         2  Medroxyprogesterone                 Amenorrhea
# 2         3  Medroxyprogesterone  Abnormal Uterine Bleeding
# 3         4  Medroxyprogesterone              Birth Control
# 4         5  Medroxyprogesterone  Abnormal Uterine Bleeding
# 5         6  Medroxyprogesterone              Birth Control
# 6         7  Medroxyprogesterone  Abnormal Uterine Bleeding
# 7         8  Medroxyprogesterone  Abnormal Uterine Bleeding
# 8         9  Medroxyprogesterone  Abnormal Uterine Bleeding
# 9        10  Medroxyprogesterone  Abnormal Uterine Bleeding
#
#                                               review  rating       date  \
# 0  "Been on the depo injection since January 2015...       3  28-Oct-15
# 1  "I&#039;m 21 years old and recently found out ...      10  27-Oct-15
# 2  "I have been on the shot 11 years and until a ...       8  27-Oct-15
# 3  "Ive had four shots at this point. I was on bi...       9  26-Oct-15
# 4  "I had a total of 3 shots. I got my first one ...       1  25-Oct-15
# 5  "This is a horrible shot!! I got my first shot...       1  24-Oct-15
# 6  "I&#039;m 18 and got this for heavy bleeding. ...       5  22-Oct-15
# 7  "Im 19 and have been having heavy and painful ...       5  21-Oct-15
# 8  "I&#039;m a 30 year old woman. I got the shot ...       2  21-Oct-15
# 9  "I&#039;m 17 years old and I got shot in Augus...       7  20-Oct-15
#
#    usefulcount
# 0            4
# 1           11
# 2            7
# 3           12
# 4            4
# 5            3
# 6            6
# 7            2
# 8            5
# 9            2

# %%
# Total unique conditions in the dataset
print (df_data['condition'].nunique(), "\n")

print ("some of the conditions are : ", df_data['condition'].unique()[0:10])
# Out:
# 916
#
# some of the conditions are :  ['Abnormal Uterine Bleeding' 'Amenorrhea' 'Birth Control' 'Endometriosis'
#  'Endometrial Hyperplasia, Prophylaxis' 'Renal Cell Carcinoma'
#  'Not Listed / Othe' 'Eye Redness' 'Benign Prostatic Hyperplasia' 'Acne']

# %%
# top 10 drugs with rating equals 1
df_data.loc[df_data['rating'] == 1, :]['drugname'].value_counts().head(10)
# Out:
# Miconazole                            767
# Ethinyl estradiol / norethindrone     728
# Etonogestrel                          707
# Levonorgestrel                        511
# Nexplanon                             504
# Ethinyl estradiol / norgestimate      464
# Medroxyprogesterone                   443
# Depo-Provera                          417
# Tioconazole                           410
# Ethinyl estradiol / levonorgestrel    385
# Name: drugname, dtype: int64

# %%
df_data.loc[df_data.usefulcount == 0, 'drugname'].value_counts()
# Out:
# Etonogestrel                         590
# Levonorgestrel                       473
# Ethinyl estradiol / norethindrone    371
# Implanon                             327
# Ethinyl estradiol / norgestimate     252
#                                     ...
# Transderm-Scop                         1
# Glimepiride / pioglitazone             1
# Estazolam                              1
# Vusion                                 1
# Menthol                                1
# Name: drugname, Length: 1487, dtype: int64

# %%
# Minimum rating in the dataset
df_data['rating'].min()
# Out:
# 1

# %%
# Converting the date in to date time format 
df_data['date'] = pd.to_datetime(df_data['date'])

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# This barplot shows the top 20 drugs with the 10/10 rating

# Setting the Parameters
sns.set(font_scale = 1.2, style = 'darkgrid')
plt.rcParams['figure.figsize'] = [15, 8]

rating = dict(df_data.loc[df_data.rating == 10, "drugname"].value_counts())
drugname = list(rating.keys())
drug_rating = list(rating.values())

sns_rating = sns.barplot(x = drugname[0:20], y = drug_rating[0:20])

sns_rating.set(title = 'Top 20 drugs with 10/10 rating', ylabel = 'Number of Ratings', xlabel = "Drug Names")
plt.setp(sns_rating.get_xticklabels(), rotation=90);

# %%
# This barplot shows the Top 20 drugs with the 1/10 rating

# Setting the Parameter
sns.set(font_scale = 1.2, style = 'whitegrid')
plt.rcParams['figure.figsize'] = [15, 8]

rating = dict(df_data.loc[df_data.rating == 1, "drugname"].value_counts())
drugname = list(rating.keys())
drug_rating = list(rating.values())

sns_rating = sns.barplot(x = drugname[0:20], y = drug_rating[0:20], palette = 'winter')

sns_rating.set(title = 'Top 20 drugs with 1/10 rating', ylabel = 'Number of Ratings', xlabel = "Drug Names")

plt.setp(sns_rating.get_xticklabels(), rotation=90);

# %%
# Word cloud of the reviews with rating equal to 10

df_rate_ten = df_data.loc[df_data.rating == 10, 'review']
k = (' '.join(df_rate_ten))

wordcloud = WordCloud(width = 1000, height = 500, background_color = 'white').generate(k)
plt.figure(figsize=(15, 10))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off');

# %%
# Word cloud of the reviews with rating equal to 1

df_rate_one = df_data.loc[df_data.rating == 1, 'review']
k1 = (' '.join(df_rate_one))

wordcloud = WordCloud(width = 1000, height = 500).generate(k1)
plt.figure(figsize=(15, 10))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off');

# %%
# This barplot shows the mean rating of the drugs per year

mean_rating = dict(df_data.groupby(df_data['date'].dt.year)['rating'].mean())
plt.rcParams['figure.figsize'] = [12, 7]
sns.set(font_scale = 1.2, style = 'whitegrid')
sns_ = sns.barplot(x = list(mean_rating.keys()), y = list(mean_rating.values()), color = 'orange');
sns_.set_xlabel("Year")
sns_.set_ylabel("Rating");

# %%
# This barplot show the top 10 conditions the people are suffering.

cond = dict(df_data['condition'].value_counts())
top_condition = list(cond.keys())[0:10]
values = list(cond.values())[0:10]
sns.set(style = 'darkgrid', font_scale = 1.3)
plt.rcParams['figure.figsize'] = [18, 7]

sns_ = sns.barplot(x = top_condition, y = values, palette = 'winter')
sns_.set_title("Top 10 conditions")
sns_.set_xlabel("Conditions")
sns_.set_ylabel("Count");

# %%
# Top 10 drugs which are used for the top condition, that is Birth Control

df = df_data[df_data['condition'] == 'Birth Control']['drugname'].value_counts()[0: 10]
sns.set(font_scale = 1.2, style = 'darkgrid')

sns_ = sns.barplot(x = df.index, y = df.values, palette = 'summer')
sns_.set_xlabel('Drug Names')
sns_.set_title("Top 10 Drugs used for Birth Control")
plt.setp(sns_.get_xticklabels(), rotation = 90);

# %%
# Distribution of the useful count
sns.set(style = 'whitegrid', font_scale = 1.3)
plt.rcParams['figure.figsize'] = [12, 7]
sns.distplot(df_data['usefulcount'].dropna())
# Out:
# <AxesSubplot: xlabel='usefulcount', ylabel='Density'>

# %%
# This barplot shows the number of reviews per year
df = df_data['date'].dt.year.value_counts()
df = df.sort_index()

sns_ = sns.barplot(x = df.index, y = df.values, color = 'mediumaquamarine')
sns_.set_title("Number of reviews per year")
sns_.set_xlabel("Year");

# %%
# Heatmap of the correlation matrix
plt.rcParams['figure.figsize'] = [7,5]
sns.set(font_scale = 1.2)
corr = df_data.select_dtypes(include = 'int64').corr()
sns_heat = sns.heatmap(corr, annot = True, vmin=-1, vmax=1, center=0,
            cmap=sns.diverging_palette(20, 220, n=200), square=True);
plt.setp(sns_heat.get_xticklabels(), rotation = 45);

# %% [markdown]
# #### Unigrams

# %%
import nltk
nltk.download('punkt')

# Top 20 unigrams according to the rating
df_ = df_data[['rating', 'review']]

# Add a new column indicating whether the rating is greater than 5 or not
df_['rating_group'] = df_['rating'].apply(lambda x: '>' if x > 5 else '<=')

# Apply text preprocessing steps to the entire data frame
df_['review'] = df_['review'].apply(lambda x: re.sub(r'[^\w\d\s]', ' ', x))
df_['review'] = df_['review'].apply(lambda x: x.replace("&#039;", ""))

# Concatenate all reviews in each group
df_grouped = df_.groupby('rating_group')['review'].apply(lambda x: ' '.join(x))

# Tokenize the reviews
tokens_grouped = df_grouped.apply(lambda x: word_tokenize(x))

# Get the top 20 unigrams for each group
unigrams_grouped = tokens_grouped.apply(lambda x: Counter(ngrams(x, 1)).most_common(20))

# Create two data frames for the top 20 unigrams
df_5 = pd.DataFrame(unigrams_grouped['<='], columns=['unigram', 'count'])
df_10 = pd.DataFrame(unigrams_grouped['>'], columns=['unigram', 'count'])

# Barplot that shows the top 20 unigrams
plt.rcParams['figure.figsize'] = [20,11]
fig, ax = plt.subplots(1,2)
sns.set(font_scale = 1.5, style = 'whitegrid')

sns_5 = sns.barplot(x = 'count', y = 'unigram', data = df_5, color = 'lightsteelblue', ax = ax[0])
sns_10 = sns.barplot(x = 'count', y = 'unigram', data = df_10, color = 'lightsteelblue', ax = ax[1])

# Setting axes labels
sns_5.set_title("Top 20 unigrams according for rating <= 5")
sns_10.set_title("Top 20 unigrams according for rating > 5")
sns_5.set_ylabel("Unigrams")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# Text(0, 0.5, 'Unigrams')

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# We are going to use the threshold rating of 5 for giving the sentiment, The review will have a positive sentiment (1) if rating > 5 and negative sentiment otherwise.

# %%
# Giving the Sentiment according to the ratings
df_data['sentiment_rate'] = df_data['rating'].apply(lambda x: 1 if x > 5 else 0)

# %%
def review_clean(review): 
    # changing to lower case
    lower = review.str.lower()
    
    # Replacing the repeating pattern of &#039;
    pattern_remove = lower.str.replace("&#039;", "")
    
    # Removing all the special Characters
    special_remove = pattern_remove.str.replace(r'[^\w\d\s]',' ')
    
    # Removing all the non ASCII characters
    ascii_remove = special_remove.str.replace(r'[^\x00-\x7F]+',' ')
    
    # Removing the leading and trailing Whitespaces
    whitespace_remove = ascii_remove.str.replace(r'^\s+|\s+?$','')
    
    # Replacing multiple Spaces with Single Space
    multiw_remove = whitespace_remove.str.replace(r'\s+',' ')
    
    # Replacing Two or more dots with one
    dataframe = multiw_remove.str.replace(r'\.{2,}', ' ')
    
    return dataframe

# %%
# Contraction Dictionary for the expansion

contractions_dict = {
    "ain't": "am not", "aren't": "are not", "can't": "cannot", "can't've": "cannot have", "'cause": "because",
    "could've": "could have", "couldn't": "could not", "couldn't've": "could not have", "didn't": "did not", "doesn't": "does not",
    "doesn’t": "does not", "don't": "do not", "don’t": "do not", "hadn't": "had not", "hadn't've": "had not have", "hasn't": "has not",
    "haven't": "have not", "he'd": "he had", "he'd've": "he would have", "he'll": "he will", "he'll've": "he will have", "he's": "he is",
    "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is", "i'd": "i would", "i'd've": "i would have",
    "i'll": "i will", "i'll've": "i will have", "i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would", "it'd've": "it would have",
    "it'll": "it will", "it'll've": "it will have", "it's": "it is", "let's": "let us", "ma'am": "madam", "mayn't": "may not","might've": "might have",
    "mightn't": "might not", "mightn't've": "might not have", "must've": "must have", "mustn't": "must not", "mustn't've": "must not have",
    "needn't": "need not", "needn't've": "need not have", "o'clock": "of the clock", "oughtn't": "ought not", "oughtn't've": "ought not have",
    "shan't": "shall not","sha'n't": "shall not", "shan't've": "shall not have", "she'd": "she would", "she'd've": "she would have",
    "she'll": "she will", "she'll've": "she will have", "she's": "she is", "should've": "should have", "shouldn't": "should not",
    "shouldn't've": "should not have", "so've": "so have", "so's": "so is", "that'd": "that would", "that'd've": "that would have",
    "that's": "that is", "there'd": "there would", "there'd've": "there would have", "there's": "there is", "they'd": "they would",
    "they'd've": "they would have", "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have",
    "to've": "to have", "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have",
    "we're": "we are", "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",
    "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is",
    "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have", "why's": "why is",
    "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have", "would've": "would have",
    "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all", "y’all": "you all", "y'all'd": "you all would",
    "y'all'd've": "you all would have", "y'all're": "you all are", "y'all've": "you all have", "you'd": "you would", "you'd've": "you would have",
    "you'll": "you will", "you'll've": "you will have", "you're": "you are", "you've": "you have", "ain’t": "am not", "aren’t": "are not",
    "can’t": "cannot", "can’t’ve": "cannot have", "’cause": "because", "could’ve": "could have", "couldn’t": "could not", "couldn’t’ve": "could not have",
    "didn’t": "did not", "doesn’t": "does not", "don’t": "do not", "don’t": "do not", "hadn’t": "had not", "hadn’t’ve": "had not have",
    "hasn’t": "has not", "haven’t": "have not", "he’d": "he had", "he’d’ve": "he would have", "he’ll": "he will", "he’ll’ve": "he will have",
    "he’s": "he is", "how’d": "how did", "how’d’y": "how do you", "how’ll": "how will", "how’s": "how is", "i’d": "i would", "i’d’ve": "i would have",
    "i’ll": "i will", "i’ll’ve": "i will have", "i’m": "i am", "i’ve": "i have", "isn’t": "is not", "it’d": "it would", "it’d’ve": "it would have",
    "it’ll": "it will", "it’ll’ve": "it will have", "it’s": "it is", "let’s": "let us", "ma’am": "madam", "mayn’t": "may not",
    "might’ve": "might have", "mightn’t": "might not", "mightn’t’ve": "might not have", "must’ve": "must have", "mustn’t": "must not",
    "mustn’t’ve": "must not have", "needn’t": "need not", "needn’t’ve": "need not have", "o’clock": "of the clock",
    "oughtn’t": "ought not", "oughtn’t’ve": "ought not have", "shan’t": "shall not", "sha’n’t": "shall not", "shan’t’ve": "shall not have",
    "she’d": "she would", "she’d’ve": "she would have", "she’ll": "she will", "she’ll’ve": "she will have", "she’s": "she is",
    "should’ve": "should have", "shouldn’t": "should not", "shouldn’t’ve": "should not have", "so’ve": "so have", "so’s": "so is",
    "that’d": "that would", "that’d’ve": "that would have", "that’s": "that is", "there’d": "there would", "there’d’ve": "there would have",
    "there’s": "there is", "they’d": "they would", "they’d’ve": "they would have", "they’ll": "they will", "they’ll’ve": "they will have",
    "they’re": "they are", "they’ve": "they have", "to’ve": "to have", "wasn’t": "was not", "we’d": "we would", "we’d’ve": "we would have",
    "we’ll": "we will", "we’ll’ve": "we will have", "we’re": "we are", "we’ve": "we have", "weren’t": "were not", "what’ll": "what will",
    "what’ll’ve": "what will have", "what’re": "what are", "what’s": "what is", "what’ve": "what have", "when’s": "when is",
    "when’ve": "when have", "where’d": "where did", "where’s": "where is", "where’ve": "where have", "who’ll": "who will",
    "who’ll’ve": "who will have", "who’s": "who is", "who’ve": "who have","why’s": "why is", "why’ve": "why have", "will’ve": "will have",
    "won’t": "will not", "won’t’ve": "will not have", "would’ve": "would have", "wouldn’t": "would not", "wouldn’t’ve": "would not have",
    "y’all": "you all", "y’all": "you all", "y’all’d": "you all would", "y’all’d’ve": "you all would have", "y’all’re": "you all are",
    "y’all’ve": "you all have", "you’d": "you would", "you’d’ve": "you would have", "you’ll": "you will", "you’ll’ve": "you will have",
    "you’re": "you are", "you’re": "you are", "you’ve": "you have"
}
contractions_re = re.compile('(%s)' % '|'.join(contractions_dict.keys()))

# Function expand the contractions if there's any
def expand_contractions(s, contractions_dict=contractions_dict):
    def replace(match):
        return contractions_dict[match.group(0)]
    return contractions_re.sub(replace, s)

# %%
#df_data['review_clean'] = df_data['review'].apply(review_clean)
df_data['review_clean'] = review_clean(df_data['review'])

# Expanding the contractions
df_data['review_clean'] = df_data['review_clean'].apply(lambda x: expand_contractions(x))

# Removing punctuations
df_data['review_clean'] = df_data['review_clean'].apply(lambda x: ''.join(word for word in x if word not in punctuation))

# %%
df_data.head()
# Out:
#    uniqueid             drugname                  condition  \
# 0         0  Medroxyprogesterone  Abnormal Uterine Bleeding
# 1         2  Medroxyprogesterone                 Amenorrhea
# 2         3  Medroxyprogesterone  Abnormal Uterine Bleeding
# 3         4  Medroxyprogesterone              Birth Control
# 4         5  Medroxyprogesterone  Abnormal Uterine Bleeding
#
#                                               review  rating       date  \
# 0  "Been on the depo injection since January 2015...       3 2015-10-28
# 1  "I&#039;m 21 years old and recently found out ...      10 2015-10-27
# 2  "I have been on the shot 11 years and until a ...       8 2015-10-27
# 3  "Ive had four shots at this point. I was on bi...       9 2015-10-26
# 4  "I had a total of 3 shots. I got my first one ...       1 2015-10-25
#
#    usefulcount  sentiment_rate  \
# 0            4               0
# 1           11               1
# 2            7               1
# 3           12               1
# 4            4               0
#
#                                         review_clean
# 0  been on the depo injection since january 2015 ...
# 1  im 21 years old and recently found out i might...
# 2  i have been on the shot 11 years and until a m...
# 3  ive had four shots at this point i was on birt...
# 4  i had a total of 3 shots i got my first one be...

# %%
# Removing the stopwords
df_data['review_clean'] = df_data['review_clean'].apply(lambda x: ' '.join(word for word in x.split() if word not in stop_words))

# %%
# Removing the word stems using the Snowball Stemmer
Snow_ball = SnowballStemmer("english")
df_data['review_clean'] = df_data['review_clean'].apply(lambda x: " ".join(Snow_ball.stem(word) for word in x.split()))

# %%
df_data['review_clean'].head(20)
# Out:
# 0     depo inject sinc januari 2015 bleed stop anoth...
# 1     im 21 year old recent found might pcos havent ...
# 2     shot 11 year month ago never 1 period even spo...
# 3     ive four shot point birth control pill year du...
# 4     total 3 shot got first one leav hospit give bi...
# 5     horribl shot got first shot august ever sinc e...
# 6     im 18 got heavi bleed ive alway heard bc make ...
# 7     im 19 heavi pain period sinc forev got depo sh...
# 8     im 30 year old woman got shot august 9th bleed...
# 9     im 17 year old got shot august 2015 person don...
# 10    first month awesom absolut wonder start light ...
# 11    start depo shot year ago origin bled 3 week da...
# 12    im 24 ive 2 year quit period last 3 week first...
# 13    im 17 went depo heavi bleed like heavi would g...
# 14    love conveni one shot everi three month look b...
# 15    1st shot sept 2nd nonstop bleed sinc side effe...
# 16    took shot safe im young teenag sexual activ bi...
# 17    ive shot 2 year amp one complaint skin couldnt...
# 18    oh man first shot great minim bleed second sho...
# 19    got shot 6 week post partum nurs seen high rec...
# Name: review_clean, dtype: object

# %%
# Separating the day, month and year from the Date

df_data['day'] = df_data['date'].dt.day
df_data['month'] = df_data['date'].dt.month
df_data['year'] = df_data['date'].dt.year

# %%
df_data.head()
# Out:
#    uniqueid             drugname                  condition  \
# 0         0  Medroxyprogesterone  Abnormal Uterine Bleeding
# 1         2  Medroxyprogesterone                 Amenorrhea
# 2         3  Medroxyprogesterone  Abnormal Uterine Bleeding
# 3         4  Medroxyprogesterone              Birth Control
# 4         5  Medroxyprogesterone  Abnormal Uterine Bleeding
#
#                                               review  rating       date  \
# 0  "Been on the depo injection since January 2015...       3 2015-10-28
# 1  "I&#039;m 21 years old and recently found out ...      10 2015-10-27
# 2  "I have been on the shot 11 years and until a ...       8 2015-10-27
# 3  "Ive had four shots at this point. I was on bi...       9 2015-10-26
# 4  "I had a total of 3 shots. I got my first one ...       1 2015-10-25
#
#    usefulcount  sentiment_rate  \
# 0            4               0
# 1           11               1
# 2            7               1
# 3           12               1
# 4            4               0
#
#                                         review_clean  day  month  year
# 0  depo inject sinc januari 2015 bleed stop anoth...   28     10  2015
# 1  im 21 year old recent found might pcos havent ...   27     10  2015
# 2  shot 11 year month ago never 1 period even spo...   27     10  2015
# 3  ive four shot point birth control pill year du...   26     10  2015
# 4  total 3 shot got first one leav hospit give bi...   25     10  2015

# %%
def sentiment(review):
    # Sentiment polarity of the reviews
    pol = []
    for i in review:
        analysis = TextBlob(i)
        pol.append(analysis.sentiment.polarity)
    return pol

# %%
df_data['sentiment'] = sentiment(df_data['review'])

# %%
df_data['sentiment_clean'] = sentiment(df_data['review_clean'])

# %%
np.corrcoef(df_data['sentiment'], df_data['rating'])
# Out:
# array([[1.       , 0.3481753],
#        [0.3481753, 1.       ]])

# %%
np.corrcoef(df_data['sentiment_clean'], df_data['rating'])
# Out:
# array([[1.        , 0.23328381],
#        [0.23328381, 1.        ]])

# %% [markdown]
# The Correlation coefficient between the sentiment of the uncleaned review with rating is greater than the cleaned review, so now lets try without the snowball stemmer and without removing the stopwords.

# %%
# Cleaning the reviews without removing the stop words and using snowball stemmer

df_data['review_clean_ss'] = review_clean(df_data['review'])

df_data['review_clean_ss'] = df_data['review_clean_ss'].apply(lambda x: expand_contractions(x))

df_data['review_clean_ss'] = df_data['review_clean_ss'].apply(lambda x: ''.join(word for word in x if word not in punctuation))

df_data['sentiment_clean_ss'] = sentiment(df_data['review_clean_ss'])

# %%
np.corrcoef(df_data['sentiment_clean_ss'], df_data['rating'])
# Out:
# array([[1.        , 0.34600372],
#        [0.34600372, 1.        ]])

# %%
df_data.head(10)
# Out:
#    uniqueid             drugname                  condition  \
# 0         0  Medroxyprogesterone  Abnormal Uterine Bleeding
# 1         2  Medroxyprogesterone                 Amenorrhea
# 2         3  Medroxyprogesterone  Abnormal Uterine Bleeding
# 3         4  Medroxyprogesterone              Birth Control
# 4         5  Medroxyprogesterone  Abnormal Uterine Bleeding
# 5         6  Medroxyprogesterone              Birth Control
# 6         7  Medroxyprogesterone  Abnormal Uterine Bleeding
# 7         8  Medroxyprogesterone  Abnormal Uterine Bleeding
# 8         9  Medroxyprogesterone  Abnormal Uterine Bleeding
# 9        10  Medroxyprogesterone  Abnormal Uterine Bleeding
#
#                                               review  rating       date  \
# 0  "Been on the depo injection since January 2015...       3 2015-10-28
# 1  "I&#039;m 21 years old and recently found out ...      10 2015-10-27
# 2  "I have been on the shot 11 years and until a ...       8 2015-10-27
# 3  "Ive had four shots at this point. I was on bi...       9 2015-10-26
# 4  "I had a total of 3 shots. I got my first one ...       1 2015-10-25
# 5  "This is a horrible shot!! I got my first shot...       1 2015-10-24
# 6  "I&#039;m 18 and got this for heavy bleeding. ...       5 2015-10-22
# 7  "Im 19 and have been having heavy and painful ...       5 2015-10-21
# 8  "I&#039;m a 30 year old woman. I got the shot ...       2 2015-10-21
# 9  "I&#039;m 17 years old and I got shot in Augus...       7 2015-10-20
#
#    usefulcount  sentiment_rate  \
# 0            4               0
# 1           11               1
# 2            7               1
# 3           12               1
# 4            4               0
# 5            3               0
# 6            6               0
# 7            2               0
# 8            5               0
# 9            2               1
#
#                                         review_clean  day  month  year  \
# 0  depo inject sinc januari 2015 bleed stop anoth...   28     10  2015
# 1  im 21 year old recent found might pcos havent ...   27     10  2015
# 2  shot 11 year month ago never 1 period even spo...   27     10  2015
# 3  ive four shot point birth control pill year du...   26     10  2015
# 4  total 3 shot got first one leav hospit give bi...   25     10  2015
# 5  horribl shot got first shot august ever sinc e...   24     10  2015
# 6  im 18 got heavi bleed ive alway heard bc make ...   22     10  2015
# 7  im 19 heavi pain period sinc forev got depo sh...   21     10  2015
# 8  im 30 year old woman got shot august 9th bleed...   21     10  2015
# 9  im 17 year old got shot august 2015 person don...   20     10  2015
#
#    sentiment  sentiment_clean  \
# 0  -0.287798        -0.127381
# 1   0.175357         0.161429
# 2  -0.210000         0.233333
# 3  -0.022500         0.069444
# 4   0.044872         0.103333
# 5   0.000321         0.013235
# 6  -0.056692         0.098052
# 7   0.030995         0.068750
# 8   0.265309         0.288889
# 9  -0.047222        -0.022500
#
#                                      review_clean_ss  sentiment_clean_ss
# 0  been on the depo injection since january 2015 ...           -0.160714
# 1  im 21 years old and recently found out i might...            0.175357
# 2  i have been on the shot 11 years and until a m...           -0.210000
# 3  ive had four shots at this point i was on birt...           -0.033333
# 4  i had a total of 3 shots i got my first one be...            0.044872
# 5  this is a horrible shot i got my first shot in...            0.000321
# 6  im 18 and got this for heavy bleeding ive alwa...           -0.065025
# 7  im 19 and have been having heavy and painful p...            0.026923
# 8  im a 30 year old woman i got the shot on augus...            0.265309
# 9  im 17 years old and i got shot in august 2015 ...           -0.047222

# %% [markdown]
# ## Feature Engineering

# %%
#Word count in each review
df_data['count_word']=df_data["review_clean_ss"].apply(lambda x: len(str(x).split()))

#Unique word count 
df_data['count_unique_word']=df_data["review_clean_ss"].apply(lambda x: len(set(str(x).split())))

#Letter count
df_data['count_letters']=df_data["review_clean_ss"].apply(lambda x: len(str(x)))

#punctuation count
df_data["count_punctuations"] = df_data["review"].apply(lambda x: len([c for c in str(x) if c in string.punctuation]))

#upper case words count
df_data["count_words_upper"] = df_data["review"].apply(lambda x: len([w for w in str(x).split() if w.isupper()]))

#title case words count
df_data["count_words_title"] = df_data["review"].apply(lambda x: len([w for w in str(x).split() if w.istitle()]))

#Number of stopwords
df_data["count_stopwords"] = df_data["review"].apply(lambda x: len([w for w in str(x).lower().split() if w in stop_words]))

#Average length of the words
df_data["mean_word_len"] = df_data["review_clean_ss"].apply(lambda x: np.mean([len(w) for w in str(x).split()]))

# %%
df_data.columns
# Out:
# Index(['uniqueid', 'drugname', 'condition', 'review', 'rating', 'date',
#        'usefulcount', 'sentiment_rate', 'review_clean', 'day', 'month', 'year',
#        'sentiment', 'sentiment_clean', 'review_clean_ss', 'sentiment_clean_ss',
#        'count_word', 'count_unique_word', 'count_letters',
#        'count_punctuations', 'count_words_upper', 'count_words_title',
#        'count_stopwords', 'mean_word_len'],
#       dtype='object')

# %%
# Correlation Heatmap of the features engineered
plt.rcParams['figure.figsize'] = [17,15]
sns.set(font_scale = 1.2)
corr = df_data.select_dtypes(include = 'int64').corr()
sns_ = sns.heatmap(corr, annot = True, cmap = 'YlGnBu')
plt.setp(sns_.get_xticklabels(), rotation = 45);

# %%
# Label Encoding Drugname and Conditions
label_encoder_feat = {}
for feature in ['drugname', 'condition']:
    label_encoder_feat[feature] = LabelEncoder()
    df_data[feature] = label_encoder_feat[feature].fit_transform(df_data[feature])

# %% [markdown]
# ## Modelling

# %%
# Defining Features and splitting the data as train and test set

features = df_data[['condition', 'usefulcount', 'sentiment', 'day', 'month', 'year',
                   'sentiment_clean_ss', 'count_word', 'count_unique_word', 'count_letters',
                   'count_punctuations', 'count_words_upper', 'count_words_title',
                   'count_stopwords', 'mean_word_len']]

target = df_data['sentiment_rate']

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size = 0.3, random_state = 42)
print ("The Train set size ", X_train.shape)
print ("The Test set size ", X_test.shape)
# Out:
# The Train set size  (149708, 15)
# The Test set size  (64161, 15)

# %% [markdown]
# Model - I LightGBM

# %%
# Training Model - I

clf = LGBMClassifier(
        n_estimators=10000,
        learning_rate=0.10,
        num_leaves=30,
        subsample=.9,
        max_depth=7,
        reg_alpha=.1,
        reg_lambda=.1,
        min_split_gain=.01,
        min_child_weight=2,
        silent=-1,
        verbose=-1,
        )
model = clf.fit(X_train, y_train)

# Predictions
predictions = model.predict(X_test)
print ("The Accuracy of the model is : ", accuracy_score(y_test, predictions), '\n')
print ("The confusion Matrix is \n")
print (confusion_matrix(y_test, predictions), '\n')

print (classification_report(y_test, predictions))
# Out:
# The Accuracy of the model is :  0.8881095992892879
#
# The confusion Matrix is
#
# [[14771  4574]
#  [ 2605 42211]]
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.76      0.80     19345
#            1       0.90      0.94      0.92     44816
#
#     accuracy                           0.89     64161
#    macro avg       0.88      0.85      0.86     64161
# weighted avg       0.89      0.89      0.89     64161

# %%
# Feature Importance Plot using LGBM
plt.rcParams['figure.figsize'] = [12, 9]
sns.set(style = 'whitegrid', font_scale = 1.2)
plot_importance(model)

# %% [markdown]
# Model - II XGBClassifier

# %%
# Training Model - II

xgb_clf = XGBClassifier(n_estimator = 10000,
                    learning_rate=0.10,
                    num_leaves=30)

model_xgb = xgb_clf.fit(X_train, y_train)

# Predictions
predictions_2 = model_xgb.predict(X_test)
print ("The Accuracy of the model is : ", accuracy_score(y_test, predictions_2), '\n')
print ("The confusion Matrix is \n")
print (confusion_matrix(y_test, predictions_2), '\n')

print (classification_report(y_test, predictions_2))
# Out:
# The Accuracy of the model is :  0.7582176088277925
#
# The confusion Matrix is
#
# [[ 7374 11971]
#  [ 3542 41274]]
#
#               precision    recall  f1-score   support
#
#            0       0.68      0.38      0.49     19345
#            1       0.78      0.92      0.84     44816
#
#     accuracy                           0.76     64161
#    macro avg       0.73      0.65      0.66     64161
# weighted avg       0.75      0.76      0.73     64161

# %%
# Feature Importance Plot using XGBClassifier
from xgboost import plot_importance # plot_importance for xgboost
plt.rcParams['figure.figsize'] = [12, 9]
plot_importance(model_xgb);

# %% [markdown]
# Model - III CatBoostClassifier

# %%
# Training Model - III

cat_clf = CatBoostClassifier(iterations = 10000,
                            learning_rate = 0.5);

model_cat = cat_clf.fit(X_train, y_train);
# Out:
# 0:	learn: 0.5609381	total: 123ms	remaining: 20m 27s
# 1:	learn: 0.5277483	total: 181ms	remaining: 15m 2s
# 2:	learn: 0.5150090	total: 262ms	remaining: 14m 33s
# 3:	learn: 0.5104804	total: 341ms	remaining: 14m 13s
# 4:	learn: 0.5073163	total: 397ms	remaining: 13m 14s
# 5:	learn: 0.5055277	total: 449ms	remaining: 12m 28s
# 6:	learn: 0.5030251	total: 502ms	remaining: 11m 55s
# 7:	learn: 0.5004387	total: 555ms	remaining: 11m 32s
# 8:	learn: 0.4993898	total: 607ms	remaining: 11m 14s
# 9:	learn: 0.4983453	total: 656ms	remaining: 10m 55s
# 10:	learn: 0.4971259	total: 700ms	remaining: 10m 35s
# 11:	learn: 0.4962358	total: 749ms	remaining: 10m 23s
# 12:	learn: 0.4955659	total: 797ms	remaining: 10m 12s
# 13:	learn: 0.4950277	total: 845ms	remaining: 10m 2s
# 14:	learn: 0.4942444	total: 897ms	remaining: 9m 57s
# 15:	learn: 0.4926985	total: 947ms	remaining: 9m 51s
# 16:	learn: 0.4919432	total: 997ms	remaining: 9m 45s
# 17:	learn: 0.4912744	total: 1.05s	remaining: 9m 42s
# 18:	learn: 0.4902089	total: 1.1s	remaining: 9m 38s
# 19:	learn: 0.4897873	total: 1.15s	remaining: 9m 35s
# 20:	learn: 0.4888847	total: 1.21s	remaining: 9m 32s
# 21:	learn: 0.4883697	total: 1.26s	remaining: 9m 30s
# 22:	learn: 0.4876522	total: 1.31s	remaining: 9m 27s
# 23:	learn: 0.4871119	total: 1.44s	remaining: 9m 56s
# 24:	learn: 0.4865887	total: 1.51s	remaining: 10m 4s
# 25:	learn: 0.4861483	total: 1.59s	remaining: 10m 9s
# 26:	learn: 0.4852361	total: 1.66s	remaining: 10m 11s
# 27:	learn: 0.4845743	total: 1.73s	remaining: 10m 16s
# 28:	learn: 0.4839705	total: 1.8s	remaining: 10m 19s
# 29:	learn: 0.4828349	total: 1.89s	remaining: 10m 27s
# 30:	learn: 0.4823353	total: 1.96s	remaining: 10m 29s
# 31:	learn: 0.4815778	total: 2.03s	remaining: 10m 31s
# 32:	learn: 0.4810999	total: 2.08s	remaining: 10m 28s
# 33:	learn: 0.4805329	total: 2.13s	remaining: 10m 23s
# 34:	learn: 0.4801328	total: 2.18s	remaining: 10m 19s
# 35:	learn: 0.4794576	total: 2.23s	remaining: 10m 15s
# 36:	learn: 0.4790175	total: 2.27s	remaining: 10m 11s
# 37:	learn: 0.4784268	total: 2.32s	remaining: 10m 8s
# 38:	learn: 0.4779382	total: 2.37s	remaining: 10m 4s
# 39:	learn: 0.4772471	total: 2.42s	remaining: 10m 3s
# 40:	learn: 0.4768441	total: 2.47s	remaining: 10m
# 41:	learn: 0.4764185	total: 2.52s	remaining: 9m 57s
# 42:	learn: 0.4759478	total: 2.57s	remaining: 9m 54s
# 43:	learn: 0.4754817	total: 2.62s	remaining: 9m 51s
# 44:	learn: 0.4751309	total: 2.66s	remaining: 9m 49s
# 45:	learn: 0.4746670	total: 2.71s	remaining: 9m 46s
# 46:	learn: 0.4739258	total: 2.76s	remaining: 9m 44s
# 47:	learn: 0.4735266	total: 2.81s	remaining: 9m 42s
# 48:	learn: 0.4731244	total: 2.86s	remaining: 9m 40s
# 49:	learn: 0.4727113	total: 2.91s	remaining: 9m 38s
# 50:	learn: 0.4723328	total: 2.96s	remaining: 9m 36s
# 51:	learn: 0.4717219	total: 3s	remaining: 9m 34s
# 52:	learn: 0.4711206	total: 3.06s	remaining: 9m 33s
# 53:	learn: 0.4707133	total: 3.1s	remaining: 9m 31s
# 54:	learn: 0.4703321	total: 3.16s	remaining: 9m 30s
# 55:	learn: 0.4699682	total: 3.23s	remaining: 9m 34s
# 56:	learn: 0.4694712	total: 3.3s	remaining: 9m 35s
# 57:	learn: 0.4690666	total: 3.37s	remaining: 9m 37s
# 58:	learn: 0.4686951	total: 3.44s	remaining: 9m 39s
# 59:	learn: 0.4682427	total: 3.51s	remaining: 9m 41s
# 60:	learn: 0.4677492	total: 3.58s	remaining: 9m 42s
# 61:	learn: 0.4673321	total: 3.65s	remaining: 9m 44s
# 62:	learn: 0.4669421	total: 3.71s	remaining: 9m 46s
# 63:	learn: 0.4665194	total: 3.78s	remaining: 9m 47s
# 64:	learn: 0.4661771	total: 3.84s	remaining: 9m 47s
# 65:	learn: 0.4657972	total: 3.89s	remaining: 9m 46s
# 66:	learn: 0.4654330	total: 3.94s	remaining: 9m 44s
# 67:	learn: 0.4649756	total: 3.99s	remaining: 9m 43s
# 68:	learn: 0.4645128	total: 4.04s	remaining: 9m 41s
# 69:	learn: 0.4644973	total: 4.08s	remaining: 9m 39s
# 70:	learn: 0.4641665	total: 4.13s	remaining: 9m 38s
# 71:	learn: 0.4639077	total: 4.18s	remaining: 9m 37s
# 72:	learn: 0.4635803	total: 4.24s	remaining: 9m 36s
# 73:	learn: 0.4632643	total: 4.28s	remaining: 9m 34s
# 74:	learn: 0.4629434	total: 4.33s	remaining: 9m 32s
# 75:	learn: 0.4624201	total: 4.38s	remaining: 9m 31s
# 76:	learn: 0.4620655	total: 4.42s	remaining: 9m 30s
# 77:	learn: 0.4617974	total: 4.47s	remaining: 9m 29s
# 78:	learn: 0.4613708	total: 4.52s	remaining: 9m 27s
# 79:	learn: 0.4609118	total: 4.57s	remaining: 9m 27s
# 80:	learn: 0.4604630	total: 4.63s	remaining: 9m 26s
# 81:	learn: 0.4596951	total: 4.68s	remaining: 9m 26s
# 82:	learn: 0.4593999	total: 4.74s	remaining: 9m 25s
# 83:	learn: 0.4589448	total: 4.78s	remaining: 9m 24s
# 84:	learn: 0.4585651	total: 4.83s	remaining: 9m 23s
# 85:	learn: 0.4581916	total: 4.88s	remaining: 9m 22s
# 86:	learn: 0.4578052	total: 4.93s	remaining: 9m 21s
# 87:	learn: 0.4574206	total: 4.98s	remaining: 9m 20s
# 88:	learn: 0.4571085	total: 5.03s	remaining: 9m 20s
# 89:	learn: 0.4568932	total: 5.08s	remaining: 9m 19s
# 90:	learn: 0.4565440	total: 5.13s	remaining: 9m 18s
# 91:	learn: 0.4563818	total: 5.2s	remaining: 9m 20s
# 92:	learn: 0.4561959	total: 5.25s	remaining: 9m 19s
# 93:	learn: 0.4559393	total: 5.3s	remaining: 9m 18s
# 94:	learn: 0.4556362	total: 5.36s	remaining: 9m 18s
# 95:	learn: 0.4548832	total: 5.41s	remaining: 9m 18s
# 96:	learn: 0.4545087	total: 5.46s	remaining: 9m 17s
# 97:	learn: 0.4541708	total: 5.51s	remaining: 9m 17s
# 98:	learn: 0.4538284	total: 5.57s	remaining: 9m 16s
# 99:	learn: 0.4535492	total: 5.61s	remaining: 9m 15s
# 100:	learn: 0.4532252	total: 5.66s	remaining: 9m 15s
# 101:	learn: 0.4529645	total: 5.71s	remaining: 9m 14s
# 102:	learn: 0.4526484	total: 5.76s	remaining: 9m 13s
# 103:	learn: 0.4523031	total: 5.81s	remaining: 9m 12s
# 104:	learn: 0.4519295	total: 5.86s	remaining: 9m 12s
# 105:	learn: 0.4516121	total: 5.91s	remaining: 9m 11s
# 106:	learn: 0.4513083	total: 5.96s	remaining: 9m 11s
# 107:	learn: 0.4513051	total: 6s	remaining: 9m 9s
# 108:	learn: 0.4509158	total: 6.05s	remaining: 9m 9s
# 109:	learn: 0.4506800	total: 6.11s	remaining: 9m 9s
# 110:	learn: 0.4502875	total: 6.16s	remaining: 9m 8s
# 111:	learn: 0.4500134	total: 6.21s	remaining: 9m 7s
# 112:	learn: 0.4496750	total: 6.25s	remaining: 9m 7s
# 113:	learn: 0.4493314	total: 6.3s	remaining: 9m 6s
# 114:	learn: 0.4490512	total: 6.35s	remaining: 9m 5s
# 115:	learn: 0.4488029	total: 6.4s	remaining: 9m 5s
# 116:	learn: 0.4485098	total: 6.45s	remaining: 9m 4s
# 117:	learn: 0.4481542	total: 6.5s	remaining: 9m 4s
# 118:	learn: 0.4478643	total: 6.55s	remaining: 9m 3s
# 119:	learn: 0.4475221	total: 6.6s	remaining: 9m 3s
# 120:	learn: 0.4472615	total: 6.64s	remaining: 9m 2s
# 121:	learn: 0.4470231	total: 6.69s	remaining: 9m 1s
# 122:	learn: 0.4467301	total: 6.74s	remaining: 9m 1s
# 123:	learn: 0.4463893	total: 6.79s	remaining: 9m
# 124:	learn: 0.4459868	total: 6.84s	remaining: 9m
# 125:	learn: 0.4456860	total: 6.89s	remaining: 9m
# 126:	learn: 0.4453866	total: 6.94s	remaining: 8m 59s
# 127:	learn: 0.4451195	total: 7s	remaining: 8m 59s
# 128:	learn: 0.4448027	total: 7.05s	remaining: 8m 59s
# 129:	learn: 0.4445906	total: 7.1s	remaining: 8m 59s
# 130:	learn: 0.4442529	total: 7.17s	remaining: 8m 59s
# 131:	learn: 0.4439282	total: 7.23s	remaining: 9m
# 132:	learn: 0.4436462	total: 7.29s	remaining: 9m
# 133:	learn: 0.4434115	total: 7.34s	remaining: 9m
# 134:	learn: 0.4430777	total: 7.4s	remaining: 9m
# 135:	learn: 0.4426623	total: 7.45s	remaining: 9m
# 136:	learn: 0.4424295	total: 7.5s	remaining: 8m 59s
# 137:	learn: 0.4421277	total: 7.55s	remaining: 8m 59s
# 138:	learn: 0.4417783	total: 7.6s	remaining: 8m 59s
# 139:	learn: 0.4414263	total: 7.66s	remaining: 8m 59s
# 140:	learn: 0.4409805	total: 7.71s	remaining: 8m 59s
# 141:	learn: 0.4406611	total: 7.76s	remaining: 8m 58s
# 142:	learn: 0.4404063	total: 7.81s	remaining: 8m 58s
# 143:	learn: 0.4400868	total: 7.86s	remaining: 8m 58s
# 144:	learn: 0.4398410	total: 7.91s	remaining: 8m 57s
# 145:	learn: 0.4395430	total: 7.96s	remaining: 8m 57s
# 146:	learn: 0.4392837	total: 8.01s	remaining: 8m 57s
# 147:	learn: 0.4389109	total: 8.06s	remaining: 8m 56s
# 148:	learn: 0.4386154	total: 8.11s	remaining: 8m 56s
# 149:	learn: 0.4384145	total: 8.16s	remaining: 8m 56s
# 150:	learn: 0.4381592	total: 8.21s	remaining: 8m 55s
# 151:	learn: 0.4378273	total: 8.26s	remaining: 8m 55s
# 152:	learn: 0.4375546	total: 8.31s	remaining: 8m 54s
# 153:	learn: 0.4372748	total: 8.36s	remaining: 8m 54s
# 154:	learn: 0.4369497	total: 8.43s	remaining: 8m 55s
# 155:	learn: 0.4367634	total: 8.49s	remaining: 8m 56s
# 156:	learn: 0.4364997	total: 8.54s	remaining: 8m 55s
# 157:	learn: 0.4362281	total: 8.59s	remaining: 8m 55s
# 158:	learn: 0.4359408	total: 8.64s	remaining: 8m 54s
# 159:	learn: 0.4358405	total: 8.69s	remaining: 8m 54s
# 160:	learn: 0.4355449	total: 8.73s	remaining: 8m 53s
# 161:	learn: 0.4352033	total: 8.78s	remaining: 8m 53s
# 162:	learn: 0.4349087	total: 8.83s	remaining: 8m 52s
# 163:	learn: 0.4347030	total: 8.88s	remaining: 8m 52s
# 164:	learn: 0.4343683	total: 8.93s	remaining: 8m 52s
# 165:	learn: 0.4341219	total: 8.98s	remaining: 8m 51s
# 166:	learn: 0.4337501	total: 9.03s	remaining: 8m 51s
# 167:	learn: 0.4334352	total: 9.08s	remaining: 8m 51s
# 168:	learn: 0.4332133	total: 9.13s	remaining: 8m 51s
# 169:	learn: 0.4328752	total: 9.21s	remaining: 8m 52s
# 170:	learn: 0.4325932	total: 9.27s	remaining: 8m 52s
# 171:	learn: 0.4323300	total: 9.32s	remaining: 8m 52s
# 172:	learn: 0.4319919	total: 9.37s	remaining: 8m 52s
# 173:	learn: 0.4316556	total: 9.42s	remaining: 8m 52s
# 174:	learn: 0.4314265	total: 9.47s	remaining: 8m 51s
# 175:	learn: 0.4310252	total: 9.52s	remaining: 8m 51s
# 176:	learn: 0.4306709	total: 9.57s	remaining: 8m 51s
# 177:	learn: 0.4304357	total: 9.62s	remaining: 8m 51s
# 178:	learn: 0.4301712	total: 9.68s	remaining: 8m 50s
# 179:	learn: 0.4299050	total: 9.73s	remaining: 8m 50s
# 180:	learn: 0.4296802	total: 9.78s	remaining: 8m 50s
# 181:	learn: 0.4293807	total: 9.83s	remaining: 8m 50s
# 182:	learn: 0.4291656	total: 9.88s	remaining: 8m 49s
# 183:	learn: 0.4288284	total: 9.92s	remaining: 8m 49s
# 184:	learn: 0.4285386	total: 9.97s	remaining: 8m 48s
# 185:	learn: 0.4282719	total: 10s	remaining: 8m 48s
# 186:	learn: 0.4280892	total: 10.1s	remaining: 8m 48s
# 187:	learn: 0.4277767	total: 10.1s	remaining: 8m 48s
# 188:	learn: 0.4275331	total: 10.2s	remaining: 8m 48s
# 189:	learn: 0.4272801	total: 10.2s	remaining: 8m 48s
# 190:	learn: 0.4270500	total: 10.3s	remaining: 8m 47s
# 191:	learn: 0.4267652	total: 10.3s	remaining: 8m 47s
# 192:	learn: 0.4265896	total: 10.4s	remaining: 8m 47s
# 193:	learn: 0.4263112	total: 10.4s	remaining: 8m 47s
# 194:	learn: 0.4259997	total: 10.5s	remaining: 8m 46s
# 195:	learn: 0.4256631	total: 10.5s	remaining: 8m 46s
# 196:	learn: 0.4254787	total: 10.6s	remaining: 8m 46s
# 197:	learn: 0.4252748	total: 10.6s	remaining: 8m 46s
# 198:	learn: 0.4249743	total: 10.7s	remaining: 8m 45s
# 199:	learn: 0.4247025	total: 10.7s	remaining: 8m 45s
# 200:	learn: 0.4244735	total: 10.8s	remaining: 8m 45s
# 201:	learn: 0.4243147	total: 10.8s	remaining: 8m 44s
# 202:	learn: 0.4240275	total: 10.9s	remaining: 8m 44s
# 203:	learn: 0.4236540	total: 10.9s	remaining: 8m 44s
# 204:	learn: 0.4234050	total: 11s	remaining: 8m 43s
# 205:	learn: 0.4232023	total: 11s	remaining: 8m 43s
# 206:	learn: 0.4229327	total: 11.1s	remaining: 8m 43s
# 207:	learn: 0.4226183	total: 11.1s	remaining: 8m 43s
# 208:	learn: 0.4223858	total: 11.2s	remaining: 8m 44s
# 209:	learn: 0.4220935	total: 11.3s	remaining: 8m 47s
# 210:	learn: 0.4218335	total: 11.4s	remaining: 8m 48s
# 211:	learn: 0.4216324	total: 11.4s	remaining: 8m 48s
# 212:	learn: 0.4213839	total: 11.5s	remaining: 8m 48s
# 213:	learn: 0.4211601	total: 11.6s	remaining: 8m 49s
# 214:	learn: 0.4208586	total: 11.6s	remaining: 8m 49s
# 215:	learn: 0.4205863	total: 11.7s	remaining: 8m 49s
# 216:	learn: 0.4203194	total: 11.7s	remaining: 8m 49s
# 217:	learn: 0.4203157	total: 11.8s	remaining: 8m 48s
# 218:	learn: 0.4200316	total: 11.8s	remaining: 8m 48s
# 219:	learn: 0.4197216	total: 11.9s	remaining: 8m 48s
# 220:	learn: 0.4195179	total: 11.9s	remaining: 8m 48s
# 221:	learn: 0.4193432	total: 12s	remaining: 8m 48s
# 222:	learn: 0.4190485	total: 12.1s	remaining: 8m 48s
# 223:	learn: 0.4187884	total: 12.1s	remaining: 8m 48s
# 224:	learn: 0.4185064	total: 12.2s	remaining: 8m 47s
# 225:	learn: 0.4182666	total: 12.2s	remaining: 8m 47s
# 226:	learn: 0.4179874	total: 12.3s	remaining: 8m 47s
# 227:	learn: 0.4177225	total: 12.3s	remaining: 8m 48s
# 228:	learn: 0.4174756	total: 12.4s	remaining: 8m 47s
# 229:	learn: 0.4172616	total: 12.4s	remaining: 8m 47s
# 230:	learn: 0.4170692	total: 12.5s	remaining: 8m 47s
# 231:	learn: 0.4168455	total: 12.5s	remaining: 8m 46s
# 232:	learn: 0.4165884	total: 12.6s	remaining: 8m 46s
# 233:	learn: 0.4163911	total: 12.6s	remaining: 8m 46s
# 234:	learn: 0.4161613	total: 12.7s	remaining: 8m 45s
# 235:	learn: 0.4160013	total: 12.7s	remaining: 8m 45s
# 236:	learn: 0.4158205	total: 12.8s	remaining: 8m 45s
# 237:	learn: 0.4155443	total: 12.8s	remaining: 8m 45s
# 238:	learn: 0.4153081	total: 12.8s	remaining: 8m 44s
# 239:	learn: 0.4150497	total: 12.9s	remaining: 8m 44s
# 240:	learn: 0.4147681	total: 13s	remaining: 8m 44s
# 241:	learn: 0.4145428	total: 13s	remaining: 8m 44s
# 242:	learn: 0.4143593	total: 13s	remaining: 8m 43s
# 243:	learn: 0.4141193	total: 13.1s	remaining: 8m 43s
# 244:	learn: 0.4139404	total: 13.1s	remaining: 8m 43s
# 245:	learn: 0.4136437	total: 13.2s	remaining: 8m 43s
# 246:	learn: 0.4134787	total: 13.2s	remaining: 8m 42s
# 247:	learn: 0.4132263	total: 13.3s	remaining: 8m 42s
# 248:	learn: 0.4130151	total: 13.4s	remaining: 8m 43s
# 249:	learn: 0.4126140	total: 13.4s	remaining: 8m 43s
# 250:	learn: 0.4124476	total: 13.5s	remaining: 8m 42s
# 251:	learn: 0.4121477	total: 13.5s	remaining: 8m 42s
# 252:	learn: 0.4118512	total: 13.6s	remaining: 8m 42s
# 253:	learn: 0.4116166	total: 13.6s	remaining: 8m 42s
# 254:	learn: 0.4114211	total: 13.7s	remaining: 8m 42s
# 255:	learn: 0.4112782	total: 13.7s	remaining: 8m 41s
# 256:	learn: 0.4109503	total: 13.8s	remaining: 8m 41s
# 257:	learn: 0.4107646	total: 13.8s	remaining: 8m 41s
# 258:	learn: 0.4105335	total: 13.9s	remaining: 8m 41s
# 259:	learn: 0.4102946	total: 13.9s	remaining: 8m 41s
# 260:	learn: 0.4100785	total: 14s	remaining: 8m 40s
# 261:	learn: 0.4098353	total: 14s	remaining: 8m 40s
# 262:	learn: 0.4096267	total: 14.1s	remaining: 8m 40s
# 263:	learn: 0.4093553	total: 14.1s	remaining: 8m 40s
# 264:	learn: 0.4090658	total: 14.2s	remaining: 8m 40s
# 265:	learn: 0.4087977	total: 14.2s	remaining: 8m 39s
# 266:	learn: 0.4086110	total: 14.3s	remaining: 8m 39s
# 267:	learn: 0.4083685	total: 14.3s	remaining: 8m 39s
# 268:	learn: 0.4080940	total: 14.4s	remaining: 8m 39s
# 269:	learn: 0.4079365	total: 14.4s	remaining: 8m 40s
# 270:	learn: 0.4077270	total: 14.5s	remaining: 8m 40s
# 271:	learn: 0.4073935	total: 14.5s	remaining: 8m 40s
# 272:	learn: 0.4072729	total: 14.6s	remaining: 8m 40s
# 273:	learn: 0.4070436	total: 14.6s	remaining: 8m 39s
# 274:	learn: 0.4067038	total: 14.7s	remaining: 8m 39s
# 275:	learn: 0.4064677	total: 14.7s	remaining: 8m 39s
# 276:	learn: 0.4062910	total: 14.8s	remaining: 8m 39s
# 277:	learn: 0.4060555	total: 14.8s	remaining: 8m 39s
# 278:	learn: 0.4058729	total: 14.9s	remaining: 8m 38s
# 279:	learn: 0.4055967	total: 14.9s	remaining: 8m 38s
# 280:	learn: 0.4053870	total: 15s	remaining: 8m 38s
# 281:	learn: 0.4051713	total: 15s	remaining: 8m 38s
# 282:	learn: 0.4049310	total: 15.1s	remaining: 8m 38s
# 283:	learn: 0.4046029	total: 15.1s	remaining: 8m 37s
# 284:	learn: 0.4042892	total: 15.2s	remaining: 8m 37s
# 285:	learn: 0.4039718	total: 15.2s	remaining: 8m 37s
# 286:	learn: 0.4036600	total: 15.3s	remaining: 8m 37s
# 287:	learn: 0.4033285	total: 15.4s	remaining: 8m 37s
# 288:	learn: 0.4030854	total: 15.4s	remaining: 8m 37s
# 289:	learn: 0.4028214	total: 15.5s	remaining: 8m 37s
# 290:	learn: 0.4026456	total: 15.5s	remaining: 8m 37s
# 291:	learn: 0.4024227	total: 15.6s	remaining: 8m 37s
# 292:	learn: 0.4021399	total: 15.6s	remaining: 8m 37s
# 293:	learn: 0.4019267	total: 15.7s	remaining: 8m 37s
# 294:	learn: 0.4016340	total: 15.7s	remaining: 8m 37s
# 295:	learn: 0.4014459	total: 15.8s	remaining: 8m 37s
# 296:	learn: 0.4012259	total: 15.8s	remaining: 8m 37s
# 297:	learn: 0.4010268	total: 15.9s	remaining: 8m 37s
# 298:	learn: 0.4007608	total: 15.9s	remaining: 8m 37s
# 299:	learn: 0.4006277	total: 16s	remaining: 8m 37s
# 300:	learn: 0.4003567	total: 16s	remaining: 8m 36s
# 301:	learn: 0.4001243	total: 16.1s	remaining: 8m 36s
# 302:	learn: 0.3998605	total: 16.1s	remaining: 8m 36s
# 303:	learn: 0.3995771	total: 16.2s	remaining: 8m 36s
# 304:	learn: 0.3993176	total: 16.2s	remaining: 8m 36s
# 305:	learn: 0.3991120	total: 16.3s	remaining: 8m 36s
# 306:	learn: 0.3988312	total: 16.4s	remaining: 8m 36s
# 307:	learn: 0.3985584	total: 16.4s	remaining: 8m 36s
# 308:	learn: 0.3984627	total: 16.5s	remaining: 8m 36s
# 309:	learn: 0.3982783	total: 16.5s	remaining: 8m 35s
# 310:	learn: 0.3981333	total: 16.6s	remaining: 8m 35s
# 311:	learn: 0.3978850	total: 16.6s	remaining: 8m 35s
# 312:	learn: 0.3976066	total: 16.7s	remaining: 8m 35s
# 313:	learn: 0.3974219	total: 16.7s	remaining: 8m 35s
# 314:	learn: 0.3972772	total: 16.7s	remaining: 8m 34s
# 315:	learn: 0.3970636	total: 16.8s	remaining: 8m 34s
# 316:	learn: 0.3968323	total: 16.8s	remaining: 8m 34s
# 317:	learn: 0.3966108	total: 16.9s	remaining: 8m 34s
# 318:	learn: 0.3965410	total: 16.9s	remaining: 8m 34s
# 319:	learn: 0.3963455	total: 17s	remaining: 8m 33s
# 320:	learn: 0.3961679	total: 17s	remaining: 8m 33s
# 321:	learn: 0.3960126	total: 17.1s	remaining: 8m 33s
# 322:	learn: 0.3957494	total: 17.1s	remaining: 8m 33s
# 323:	learn: 0.3956199	total: 17.2s	remaining: 8m 33s
# 324:	learn: 0.3953991	total: 17.2s	remaining: 8m 32s
# 325:	learn: 0.3951046	total: 17.3s	remaining: 8m 32s
# 326:	learn: 0.3948816	total: 17.3s	remaining: 8m 32s
# 327:	learn: 0.3946675	total: 17.4s	remaining: 8m 32s
# 328:	learn: 0.3944827	total: 17.4s	remaining: 8m 32s
# 329:	learn: 0.3941354	total: 17.5s	remaining: 8m 32s
# 330:	learn: 0.3938920	total: 17.5s	remaining: 8m 32s
# 331:	learn: 0.3937137	total: 17.6s	remaining: 8m 31s
# 332:	learn: 0.3935215	total: 17.6s	remaining: 8m 31s
# 333:	learn: 0.3933077	total: 17.7s	remaining: 8m 31s
# 334:	learn: 0.3931265	total: 17.7s	remaining: 8m 31s
# 335:	learn: 0.3929209	total: 17.8s	remaining: 8m 31s
# 336:	learn: 0.3926529	total: 17.8s	remaining: 8m 31s
# 337:	learn: 0.3925322	total: 17.9s	remaining: 8m 30s
# 338:	learn: 0.3922920	total: 17.9s	remaining: 8m 30s
# 339:	learn: 0.3920342	total: 18s	remaining: 8m 30s
# 340:	learn: 0.3918314	total: 18s	remaining: 8m 30s
# 341:	learn: 0.3915862	total: 18.1s	remaining: 8m 30s
# 342:	learn: 0.3913137	total: 18.1s	remaining: 8m 30s
# 343:	learn: 0.3911630	total: 18.2s	remaining: 8m 29s
# 344:	learn: 0.3909726	total: 18.2s	remaining: 8m 29s
# 345:	learn: 0.3907680	total: 18.3s	remaining: 8m 29s
# 346:	learn: 0.3905787	total: 18.3s	remaining: 8m 29s
# 347:	learn: 0.3904096	total: 18.4s	remaining: 8m 29s
# 348:	learn: 0.3901431	total: 18.4s	remaining: 8m 29s
# 349:	learn: 0.3898217	total: 18.5s	remaining: 8m 29s
# 350:	learn: 0.3895457	total: 18.5s	remaining: 8m 28s
# 351:	learn: 0.3892836	total: 18.6s	remaining: 8m 28s
# 352:	learn: 0.3890801	total: 18.6s	remaining: 8m 28s
# 353:	learn: 0.3888170	total: 18.7s	remaining: 8m 28s
# 354:	learn: 0.3885464	total: 18.7s	remaining: 8m 28s
# 355:	learn: 0.3883901	total: 18.8s	remaining: 8m 28s
# 356:	learn: 0.3882900	total: 18.8s	remaining: 8m 28s
# 357:	learn: 0.3880816	total: 18.9s	remaining: 8m 27s
# 358:	learn: 0.3878984	total: 18.9s	remaining: 8m 27s
# 359:	learn: 0.3877098	total: 19s	remaining: 8m 27s
# 360:	learn: 0.3874393	total: 19s	remaining: 8m 27s
# 361:	learn: 0.3871347	total: 19.1s	remaining: 8m 27s
# 362:	learn: 0.3869754	total: 19.1s	remaining: 8m 27s
# 363:	learn: 0.3867534	total: 19.1s	remaining: 8m 26s
# 364:	learn: 0.3864941	total: 19.2s	remaining: 8m 26s
# 365:	learn: 0.3862351	total: 19.2s	remaining: 8m 26s
# 366:	learn: 0.3860219	total: 19.3s	remaining: 8m 26s
# 367:	learn: 0.3859086	total: 19.4s	remaining: 8m 26s
# 368:	learn: 0.3857666	total: 19.4s	remaining: 8m 26s
# 369:	learn: 0.3855558	total: 19.5s	remaining: 8m 26s
# 370:	learn: 0.3854468	total: 19.5s	remaining: 8m 26s
# 371:	learn: 0.3851395	total: 19.6s	remaining: 8m 26s
# 372:	learn: 0.3849449	total: 19.6s	remaining: 8m 26s
# 373:	learn: 0.3847202	total: 19.7s	remaining: 8m 26s
# 374:	learn: 0.3845134	total: 19.7s	remaining: 8m 26s
# 375:	learn: 0.3843538	total: 19.8s	remaining: 8m 26s
# 376:	learn: 0.3841165	total: 19.8s	remaining: 8m 26s
# 377:	learn: 0.3839996	total: 19.9s	remaining: 8m 26s
# 378:	learn: 0.3837748	total: 19.9s	remaining: 8m 26s
# 379:	learn: 0.3835571	total: 20s	remaining: 8m 25s
# 380:	learn: 0.3832983	total: 20s	remaining: 8m 25s
# 381:	learn: 0.3832810	total: 20.1s	remaining: 8m 25s
# 382:	learn: 0.3831134	total: 20.1s	remaining: 8m 25s
# 383:	learn: 0.3829321	total: 20.2s	remaining: 8m 25s
# 384:	learn: 0.3827240	total: 20.2s	remaining: 8m 25s
# 385:	learn: 0.3825932	total: 20.3s	remaining: 8m 24s
# 386:	learn: 0.3823804	total: 20.3s	remaining: 8m 24s
# 387:	learn: 0.3822403	total: 20.4s	remaining: 8m 24s
# 388:	learn: 0.3819917	total: 20.4s	remaining: 8m 24s
# 389:	learn: 0.3817863	total: 20.5s	remaining: 8m 24s
# 390:	learn: 0.3815628	total: 20.5s	remaining: 8m 24s
# 391:	learn: 0.3813403	total: 20.6s	remaining: 8m 24s
# 392:	learn: 0.3811659	total: 20.6s	remaining: 8m 24s
# 393:	learn: 0.3809903	total: 20.7s	remaining: 8m 24s
# 394:	learn: 0.3808617	total: 20.7s	remaining: 8m 23s
# 395:	learn: 0.3805945	total: 20.8s	remaining: 8m 23s
# 396:	learn: 0.3804363	total: 20.8s	remaining: 8m 23s
# 397:	learn: 0.3802194	total: 20.9s	remaining: 8m 23s
# 398:	learn: 0.3799661	total: 20.9s	remaining: 8m 23s
# 399:	learn: 0.3797779	total: 21s	remaining: 8m 23s
# 400:	learn: 0.3796313	total: 21s	remaining: 8m 23s
# 401:	learn: 0.3794685	total: 21.1s	remaining: 8m 22s
# 402:	learn: 0.3792010	total: 21.1s	remaining: 8m 22s
# 403:	learn: 0.3788740	total: 21.2s	remaining: 8m 22s
# 404:	learn: 0.3786101	total: 21.2s	remaining: 8m 22s
# 405:	learn: 0.3783148	total: 21.3s	remaining: 8m 22s
# 406:	learn: 0.3780817	total: 21.3s	remaining: 8m 22s
# 407:	learn: 0.3779321	total: 21.4s	remaining: 8m 22s
# 408:	learn: 0.3777559	total: 21.4s	remaining: 8m 22s
# 409:	learn: 0.3775506	total: 21.5s	remaining: 8m 22s
# 410:	learn: 0.3772351	total: 21.5s	remaining: 8m 22s
# 411:	learn: 0.3770251	total: 21.6s	remaining: 8m 22s
# 412:	learn: 0.3768663	total: 21.6s	remaining: 8m 22s
# 413:	learn: 0.3767501	total: 21.7s	remaining: 8m 22s
# 414:	learn: 0.3765506	total: 21.7s	remaining: 8m 21s
# 415:	learn: 0.3763047	total: 21.8s	remaining: 8m 22s
# 416:	learn: 0.3761230	total: 21.8s	remaining: 8m 21s
# 417:	learn: 0.3758900	total: 21.9s	remaining: 8m 21s
# 418:	learn: 0.3756763	total: 22s	remaining: 8m 22s
# 419:	learn: 0.3754354	total: 22s	remaining: 8m 22s
# 420:	learn: 0.3752786	total: 22.1s	remaining: 8m 22s
# 421:	learn: 0.3749801	total: 22.1s	remaining: 8m 22s
# 422:	learn: 0.3747227	total: 22.2s	remaining: 8m 22s
# 423:	learn: 0.3744832	total: 22.3s	remaining: 8m 23s
# 424:	learn: 0.3742280	total: 22.4s	remaining: 8m 23s
# 425:	learn: 0.3740617	total: 22.4s	remaining: 8m 23s
# 426:	learn: 0.3738804	total: 22.5s	remaining: 8m 23s
# 427:	learn: 0.3736182	total: 22.5s	remaining: 8m 23s
# 428:	learn: 0.3734867	total: 22.6s	remaining: 8m 23s
# 429:	learn: 0.3733088	total: 22.6s	remaining: 8m 23s
# 430:	learn: 0.3731548	total: 22.7s	remaining: 8m 23s
# 431:	learn: 0.3729996	total: 22.7s	remaining: 8m 22s
# 432:	learn: 0.3728914	total: 22.8s	remaining: 8m 22s
# 433:	learn: 0.3726556	total: 22.8s	remaining: 8m 22s
# 434:	learn: 0.3724086	total: 22.9s	remaining: 8m 22s
# 435:	learn: 0.3722371	total: 22.9s	remaining: 8m 22s
# 436:	learn: 0.3720966	total: 22.9s	remaining: 8m 22s
# 437:	learn: 0.3719113	total: 23s	remaining: 8m 21s
# 438:	learn: 0.3718078	total: 23s	remaining: 8m 21s
# 439:	learn: 0.3716627	total: 23.1s	remaining: 8m 21s
# 440:	learn: 0.3714551	total: 23.1s	remaining: 8m 21s
# 441:	learn: 0.3712959	total: 23.2s	remaining: 8m 21s
# 442:	learn: 0.3710525	total: 23.2s	remaining: 8m 21s
# 443:	learn: 0.3708494	total: 23.3s	remaining: 8m 21s
# 444:	learn: 0.3706717	total: 23.3s	remaining: 8m 21s
# 445:	learn: 0.3705134	total: 23.4s	remaining: 8m 20s
# 446:	learn: 0.3702798	total: 23.4s	remaining: 8m 20s
# 447:	learn: 0.3700358	total: 23.5s	remaining: 8m 20s
# 448:	learn: 0.3699020	total: 23.5s	remaining: 8m 20s
# 449:	learn: 0.3697107	total: 23.6s	remaining: 8m 20s
# 450:	learn: 0.3695920	total: 23.6s	remaining: 8m 20s
# 451:	learn: 0.3693722	total: 23.7s	remaining: 8m 20s
# 452:	learn: 0.3691979	total: 23.7s	remaining: 8m 20s
# 453:	learn: 0.3690363	total: 23.8s	remaining: 8m 20s
# 454:	learn: 0.3689214	total: 23.8s	remaining: 8m 19s
# 455:	learn: 0.3686922	total: 23.9s	remaining: 8m 19s
# 456:	learn: 0.3684986	total: 23.9s	remaining: 8m 19s
# 457:	learn: 0.3683100	total: 24s	remaining: 8m 19s
# 458:	learn: 0.3681400	total: 24s	remaining: 8m 19s
# 459:	learn: 0.3679949	total: 24.1s	remaining: 8m 19s
# 460:	learn: 0.3678281	total: 24.1s	remaining: 8m 19s
# 461:	learn: 0.3676506	total: 24.2s	remaining: 8m 19s
# 462:	learn: 0.3674903	total: 24.2s	remaining: 8m 19s
# 463:	learn: 0.3673427	total: 24.3s	remaining: 8m 19s
# 464:	learn: 0.3671039	total: 24.3s	remaining: 8m 18s
# 465:	learn: 0.3669998	total: 24.4s	remaining: 8m 18s
# 466:	learn: 0.3668035	total: 24.4s	remaining: 8m 18s
# 467:	learn: 0.3666274	total: 24.5s	remaining: 8m 18s
# 468:	learn: 0.3664451	total: 24.5s	remaining: 8m 18s
# 469:	learn: 0.3663440	total: 24.6s	remaining: 8m 18s
# 470:	learn: 0.3661410	total: 24.6s	remaining: 8m 18s
# 471:	learn: 0.3659405	total: 24.7s	remaining: 8m 18s
# 472:	learn: 0.3657960	total: 24.7s	remaining: 8m 18s
# 473:	learn: 0.3657188	total: 24.8s	remaining: 8m 17s
# 474:	learn: 0.3654463	total: 24.8s	remaining: 8m 17s
# 475:	learn: 0.3651928	total: 24.9s	remaining: 8m 17s
# 476:	learn: 0.3649562	total: 24.9s	remaining: 8m 17s
# 477:	learn: 0.3646889	total: 25s	remaining: 8m 17s
# 478:	learn: 0.3644455	total: 25s	remaining: 8m 17s
# 479:	learn: 0.3642468	total: 25.1s	remaining: 8m 17s
# 480:	learn: 0.3640331	total: 25.1s	remaining: 8m 17s
# 481:	learn: 0.3637989	total: 25.2s	remaining: 8m 16s
# 482:	learn: 0.3636962	total: 25.2s	remaining: 8m 16s
# 483:	learn: 0.3635114	total: 25.3s	remaining: 8m 16s
# 484:	learn: 0.3633323	total: 25.3s	remaining: 8m 16s
# 485:	learn: 0.3631282	total: 25.4s	remaining: 8m 16s
# 486:	learn: 0.3628669	total: 25.4s	remaining: 8m 16s
# 487:	learn: 0.3626573	total: 25.5s	remaining: 8m 16s
# 488:	learn: 0.3624227	total: 25.5s	remaining: 8m 16s
# 489:	learn: 0.3623192	total: 25.6s	remaining: 8m 16s
# 490:	learn: 0.3621206	total: 25.6s	remaining: 8m 16s
# 491:	learn: 0.3619413	total: 25.7s	remaining: 8m 16s
# 492:	learn: 0.3617319	total: 25.7s	remaining: 8m 16s
# 493:	learn: 0.3615044	total: 25.8s	remaining: 8m 16s
# 494:	learn: 0.3613707	total: 25.8s	remaining: 8m 15s
# 495:	learn: 0.3611308	total: 25.9s	remaining: 8m 15s
# 496:	learn: 0.3611112	total: 25.9s	remaining: 8m 15s
# 497:	learn: 0.3609371	total: 26s	remaining: 8m 15s
# 498:	learn: 0.3607790	total: 26s	remaining: 8m 15s
# 499:	learn: 0.3606753	total: 26.1s	remaining: 8m 15s
# 500:	learn: 0.3604943	total: 26.1s	remaining: 8m 15s
# 501:	learn: 0.3603346	total: 26.2s	remaining: 8m 15s
# 502:	learn: 0.3600855	total: 26.2s	remaining: 8m 15s
# 503:	learn: 0.3599067	total: 26.3s	remaining: 8m 15s
# 504:	learn: 0.3597330	total: 26.4s	remaining: 8m 15s
# 505:	learn: 0.3595902	total: 26.4s	remaining: 8m 15s
# 506:	learn: 0.3594349	total: 26.5s	remaining: 8m 15s
# 507:	learn: 0.3592764	total: 26.5s	remaining: 8m 15s
# 508:	learn: 0.3590818	total: 26.6s	remaining: 8m 15s
# 509:	learn: 0.3588778	total: 26.6s	remaining: 8m 15s
# 510:	learn: 0.3587175	total: 26.7s	remaining: 8m 15s
# 511:	learn: 0.3585465	total: 26.7s	remaining: 8m 14s
# 512:	learn: 0.3582838	total: 26.8s	remaining: 8m 14s
# 513:	learn: 0.3580810	total: 26.8s	remaining: 8m 14s
# 514:	learn: 0.3578301	total: 26.9s	remaining: 8m 14s
# 515:	learn: 0.3576444	total: 26.9s	remaining: 8m 14s
# 516:	learn: 0.3574368	total: 27s	remaining: 8m 14s
# 517:	learn: 0.3572334	total: 27s	remaining: 8m 14s
# 518:	learn: 0.3570632	total: 27.1s	remaining: 8m 14s
# 519:	learn: 0.3568524	total: 27.1s	remaining: 8m 14s
# 520:	learn: 0.3566658	total: 27.2s	remaining: 8m 14s
# 521:	learn: 0.3564673	total: 27.2s	remaining: 8m 13s
# 522:	learn: 0.3563390	total: 27.3s	remaining: 8m 13s
# 523:	learn: 0.3561210	total: 27.3s	remaining: 8m 13s
# 524:	learn: 0.3559092	total: 27.4s	remaining: 8m 13s
# 525:	learn: 0.3557284	total: 27.4s	remaining: 8m 13s
# 526:	learn: 0.3555513	total: 27.5s	remaining: 8m 13s
# 527:	learn: 0.3552869	total: 27.5s	remaining: 8m 13s
# 528:	learn: 0.3550817	total: 27.6s	remaining: 8m 13s
# 529:	learn: 0.3549561	total: 27.6s	remaining: 8m 13s
# 530:	learn: 0.3547022	total: 27.7s	remaining: 8m 13s
# 531:	learn: 0.3545506	total: 27.7s	remaining: 8m 13s
# 532:	learn: 0.3544421	total: 27.8s	remaining: 8m 13s
# 533:	learn: 0.3542986	total: 27.8s	remaining: 8m 13s
# 534:	learn: 0.3541812	total: 27.9s	remaining: 8m 12s
# 535:	learn: 0.3539145	total: 27.9s	remaining: 8m 12s
# 536:	learn: 0.3537463	total: 28s	remaining: 8m 12s
# 537:	learn: 0.3535435	total: 28s	remaining: 8m 12s
# 538:	learn: 0.3533707	total: 28.1s	remaining: 8m 12s
# 539:	learn: 0.3531931	total: 28.1s	remaining: 8m 12s
# 540:	learn: 0.3530366	total: 28.2s	remaining: 8m 12s
# 541:	learn: 0.3528187	total: 28.2s	remaining: 8m 12s
# 542:	learn: 0.3526466	total: 28.3s	remaining: 8m 12s
# 543:	learn: 0.3524063	total: 28.3s	remaining: 8m 12s
# 544:	learn: 0.3522341	total: 28.4s	remaining: 8m 12s
# 545:	learn: 0.3520385	total: 28.5s	remaining: 8m 13s
# 546:	learn: 0.3518068	total: 28.6s	remaining: 8m 13s
# 547:	learn: 0.3516092	total: 28.7s	remaining: 8m 14s
# 548:	learn: 0.3514185	total: 28.7s	remaining: 8m 14s
# 549:	learn: 0.3512494	total: 28.8s	remaining: 8m 14s
# 550:	learn: 0.3511109	total: 28.8s	remaining: 8m 14s
# 551:	learn: 0.3509323	total: 28.9s	remaining: 8m 14s
# 552:	learn: 0.3507533	total: 28.9s	remaining: 8m 14s
# 553:	learn: 0.3505343	total: 29s	remaining: 8m 14s
# 554:	learn: 0.3503594	total: 29s	remaining: 8m 14s
# 555:	learn: 0.3501628	total: 29.1s	remaining: 8m 14s
# 556:	learn: 0.3500645	total: 29.1s	remaining: 8m 13s
# 557:	learn: 0.3498691	total: 29.2s	remaining: 8m 13s
# 558:	learn: 0.3496758	total: 29.2s	remaining: 8m 13s
# 559:	learn: 0.3494946	total: 29.3s	remaining: 8m 13s
# 560:	learn: 0.3492725	total: 29.3s	remaining: 8m 13s
# 561:	learn: 0.3490596	total: 29.4s	remaining: 8m 13s
# 562:	learn: 0.3488774	total: 29.4s	remaining: 8m 13s
# 563:	learn: 0.3487056	total: 29.5s	remaining: 8m 13s
# 564:	learn: 0.3485689	total: 29.5s	remaining: 8m 13s
# 565:	learn: 0.3483653	total: 29.6s	remaining: 8m 13s
# 566:	learn: 0.3481791	total: 29.7s	remaining: 8m 13s
# 567:	learn: 0.3480381	total: 29.7s	remaining: 8m 13s
# 568:	learn: 0.3479231	total: 29.8s	remaining: 8m 13s
# 569:	learn: 0.3477473	total: 29.8s	remaining: 8m 13s
# 570:	learn: 0.3474496	total: 29.9s	remaining: 8m 13s
# 571:	learn: 0.3472363	total: 29.9s	remaining: 8m 13s
# 572:	learn: 0.3470102	total: 30s	remaining: 8m 13s
# 573:	learn: 0.3468496	total: 30s	remaining: 8m 12s
# 574:	learn: 0.3466733	total: 30.1s	remaining: 8m 12s
# 575:	learn: 0.3464810	total: 30.1s	remaining: 8m 12s
# 576:	learn: 0.3463591	total: 30.2s	remaining: 8m 12s
# 577:	learn: 0.3462020	total: 30.2s	remaining: 8m 12s
# 578:	learn: 0.3459905	total: 30.3s	remaining: 8m 12s
# 579:	learn: 0.3458353	total: 30.3s	remaining: 8m 12s
# 580:	learn: 0.3456518	total: 30.4s	remaining: 8m 12s
# 581:	learn: 0.3454322	total: 30.4s	remaining: 8m 12s
# 582:	learn: 0.3452040	total: 30.5s	remaining: 8m 12s
# 583:	learn: 0.3450902	total: 30.5s	remaining: 8m 12s
# 584:	learn: 0.3449946	total: 30.6s	remaining: 8m 12s
# 585:	learn: 0.3447987	total: 30.6s	remaining: 8m 12s
# 586:	learn: 0.3446384	total: 30.7s	remaining: 8m 11s
# 587:	learn: 0.3445289	total: 30.7s	remaining: 8m 11s
# 588:	learn: 0.3443481	total: 30.8s	remaining: 8m 11s
# 589:	learn: 0.3441735	total: 30.8s	remaining: 8m 11s
# 590:	learn: 0.3439383	total: 30.9s	remaining: 8m 11s
# 591:	learn: 0.3437416	total: 30.9s	remaining: 8m 11s
# 592:	learn: 0.3435554	total: 31s	remaining: 8m 11s
# 593:	learn: 0.3434319	total: 31s	remaining: 8m 11s
# 594:	learn: 0.3432377	total: 31.1s	remaining: 8m 11s
# 595:	learn: 0.3430408	total: 31.1s	remaining: 8m 11s
# 596:	learn: 0.3428582	total: 31.2s	remaining: 8m 10s
# 597:	learn: 0.3427575	total: 31.2s	remaining: 8m 10s
# 598:	learn: 0.3426712	total: 31.3s	remaining: 8m 10s
# 599:	learn: 0.3424848	total: 31.3s	remaining: 8m 10s
# 600:	learn: 0.3422611	total: 31.4s	remaining: 8m 10s
# 601:	learn: 0.3420962	total: 31.4s	remaining: 8m 10s
# 602:	learn: 0.3418515	total: 31.5s	remaining: 8m 10s
# 603:	learn: 0.3417477	total: 31.5s	remaining: 8m 10s
# 604:	learn: 0.3416564	total: 31.6s	remaining: 8m 10s
# 605:	learn: 0.3414370	total: 31.6s	remaining: 8m 10s
# 606:	learn: 0.3412830	total: 31.7s	remaining: 8m 10s
# 607:	learn: 0.3411797	total: 31.7s	remaining: 8m 10s
# 608:	learn: 0.3410659	total: 31.8s	remaining: 8m 10s
# 609:	learn: 0.3408335	total: 31.8s	remaining: 8m 10s
# 610:	learn: 0.3407142	total: 31.9s	remaining: 8m 10s
# 611:	learn: 0.3405972	total: 31.9s	remaining: 8m 10s
# 612:	learn: 0.3404844	total: 32s	remaining: 8m 9s
# 613:	learn: 0.3403083	total: 32s	remaining: 8m 9s
# 614:	learn: 0.3401043	total: 32.1s	remaining: 8m 9s
# 615:	learn: 0.3399717	total: 32.2s	remaining: 8m 9s
# 616:	learn: 0.3398188	total: 32.2s	remaining: 8m 9s
# 617:	learn: 0.3396707	total: 32.3s	remaining: 8m 9s
# 618:	learn: 0.3394482	total: 32.3s	remaining: 8m 9s
# 619:	learn: 0.3392512	total: 32.4s	remaining: 8m 9s
# 620:	learn: 0.3390670	total: 32.4s	remaining: 8m 9s
# 621:	learn: 0.3389774	total: 32.5s	remaining: 8m 9s
# 622:	learn: 0.3387487	total: 32.5s	remaining: 8m 9s
# 623:	learn: 0.3386032	total: 32.6s	remaining: 8m 9s
# 624:	learn: 0.3383974	total: 32.6s	remaining: 8m 8s
# 625:	learn: 0.3382024	total: 32.7s	remaining: 8m 8s
# 626:	learn: 0.3380022	total: 32.7s	remaining: 8m 8s
# 627:	learn: 0.3378417	total: 32.7s	remaining: 8m 8s
# 628:	learn: 0.3376535	total: 32.8s	remaining: 8m 8s
# 629:	learn: 0.3375206	total: 32.8s	remaining: 8m 8s
# 630:	learn: 0.3373895	total: 32.9s	remaining: 8m 8s
# 631:	learn: 0.3371814	total: 32.9s	remaining: 8m 8s
# 632:	learn: 0.3369840	total: 33s	remaining: 8m 8s
# 633:	learn: 0.3368482	total: 33s	remaining: 8m 7s
# 634:	learn: 0.3366280	total: 33.1s	remaining: 8m 7s
# 635:	learn: 0.3363895	total: 33.2s	remaining: 8m 8s
# 636:	learn: 0.3362009	total: 33.3s	remaining: 8m 8s
# 637:	learn: 0.3361089	total: 33.3s	remaining: 8m 8s
# 638:	learn: 0.3360203	total: 33.4s	remaining: 8m 8s
# 639:	learn: 0.3358383	total: 33.4s	remaining: 8m 8s
# 640:	learn: 0.3357136	total: 33.5s	remaining: 8m 8s
# 641:	learn: 0.3355953	total: 33.5s	remaining: 8m 8s
# 642:	learn: 0.3354296	total: 33.6s	remaining: 8m 8s
# 643:	learn: 0.3352396	total: 33.6s	remaining: 8m 8s
# 644:	learn: 0.3350334	total: 33.7s	remaining: 8m 8s
# 645:	learn: 0.3349109	total: 33.7s	remaining: 8m 8s
# 646:	learn: 0.3348295	total: 33.8s	remaining: 8m 8s
# 647:	learn: 0.3347130	total: 33.8s	remaining: 8m 8s
# 648:	learn: 0.3345656	total: 33.9s	remaining: 8m 7s
# 649:	learn: 0.3344806	total: 33.9s	remaining: 8m 7s
# 650:	learn: 0.3343172	total: 34s	remaining: 8m 7s
# 651:	learn: 0.3341282	total: 34s	remaining: 8m 7s
# 652:	learn: 0.3340138	total: 34.1s	remaining: 8m 7s
# 653:	learn: 0.3338793	total: 34.1s	remaining: 8m 7s
# 654:	learn: 0.3337114	total: 34.2s	remaining: 8m 7s
# 655:	learn: 0.3335826	total: 34.2s	remaining: 8m 7s
# 656:	learn: 0.3333848	total: 34.3s	remaining: 8m 7s
# 657:	learn: 0.3332508	total: 34.3s	remaining: 8m 7s
# 658:	learn: 0.3330213	total: 34.4s	remaining: 8m 7s
# 659:	learn: 0.3329189	total: 34.4s	remaining: 8m 7s
# 660:	learn: 0.3327732	total: 34.5s	remaining: 8m 7s
# 661:	learn: 0.3326170	total: 34.6s	remaining: 8m 7s
# 662:	learn: 0.3324860	total: 34.6s	remaining: 8m 7s
# 663:	learn: 0.3322781	total: 34.7s	remaining: 8m 7s
# 664:	learn: 0.3321006	total: 34.7s	remaining: 8m 7s
# 665:	learn: 0.3318711	total: 34.8s	remaining: 8m 7s
# 666:	learn: 0.3317501	total: 34.8s	remaining: 8m 6s
# 667:	learn: 0.3316273	total: 34.8s	remaining: 8m 6s
# 668:	learn: 0.3314012	total: 34.9s	remaining: 8m 6s
# 669:	learn: 0.3312779	total: 34.9s	remaining: 8m 6s
# 670:	learn: 0.3311495	total: 35s	remaining: 8m 6s
# 671:	learn: 0.3309786	total: 35s	remaining: 8m 6s
# 672:	learn: 0.3308466	total: 35.1s	remaining: 8m 6s
# 673:	learn: 0.3307353	total: 35.1s	remaining: 8m 6s
# 674:	learn: 0.3305875	total: 35.2s	remaining: 8m 6s
# 675:	learn: 0.3304567	total: 35.2s	remaining: 8m 5s
# 676:	learn: 0.3302941	total: 35.3s	remaining: 8m 5s
# 677:	learn: 0.3301409	total: 35.3s	remaining: 8m 5s
# 678:	learn: 0.3299155	total: 35.4s	remaining: 8m 5s
# 679:	learn: 0.3296996	total: 35.4s	remaining: 8m 5s
# 680:	learn: 0.3295066	total: 35.5s	remaining: 8m 5s
# 681:	learn: 0.3292812	total: 35.5s	remaining: 8m 5s
# 682:	learn: 0.3291212	total: 35.6s	remaining: 8m 5s
# 683:	learn: 0.3289722	total: 35.6s	remaining: 8m 5s
# 684:	learn: 0.3288187	total: 35.7s	remaining: 8m 5s
# 685:	learn: 0.3285846	total: 35.7s	remaining: 8m 4s
# 686:	learn: 0.3283620	total: 35.8s	remaining: 8m 4s
# 687:	learn: 0.3282090	total: 35.8s	remaining: 8m 4s
# 688:	learn: 0.3281417	total: 35.9s	remaining: 8m 4s
# 689:	learn: 0.3279291	total: 35.9s	remaining: 8m 4s
# 690:	learn: 0.3278485	total: 36s	remaining: 8m 4s
# 691:	learn: 0.3276505	total: 36s	remaining: 8m 4s
# 692:	learn: 0.3275414	total: 36.1s	remaining: 8m 4s
# 693:	learn: 0.3273844	total: 36.1s	remaining: 8m 4s
# 694:	learn: 0.3272349	total: 36.2s	remaining: 8m 4s
# 695:	learn: 0.3270173	total: 36.2s	remaining: 8m 4s
# 696:	learn: 0.3268707	total: 36.3s	remaining: 8m 4s
# 697:	learn: 0.3267030	total: 36.3s	remaining: 8m 4s
# 698:	learn: 0.3264983	total: 36.4s	remaining: 8m 4s
# 699:	learn: 0.3263892	total: 36.4s	remaining: 8m 4s
# 700:	learn: 0.3261796	total: 36.5s	remaining: 8m 3s
# 701:	learn: 0.3260110	total: 36.5s	remaining: 8m 3s
# 702:	learn: 0.3258376	total: 36.6s	remaining: 8m 3s
# 703:	learn: 0.3256907	total: 36.6s	remaining: 8m 3s
# 704:	learn: 0.3254255	total: 36.7s	remaining: 8m 3s
# 705:	learn: 0.3252724	total: 36.7s	remaining: 8m 3s
# 706:	learn: 0.3250873	total: 36.8s	remaining: 8m 3s
# 707:	learn: 0.3248929	total: 36.8s	remaining: 8m 3s
# 708:	learn: 0.3246891	total: 36.9s	remaining: 8m 3s
# 709:	learn: 0.3245225	total: 36.9s	remaining: 8m 3s
# 710:	learn: 0.3243911	total: 37s	remaining: 8m 3s
# 711:	learn: 0.3242058	total: 37s	remaining: 8m 3s
# 712:	learn: 0.3240507	total: 37.1s	remaining: 8m 2s
# 713:	learn: 0.3238803	total: 37.1s	remaining: 8m 2s
# 714:	learn: 0.3237457	total: 37.2s	remaining: 8m 2s
# 715:	learn: 0.3235357	total: 37.2s	remaining: 8m 2s
# 716:	learn: 0.3233027	total: 37.3s	remaining: 8m 2s
# 717:	learn: 0.3231907	total: 37.3s	remaining: 8m 2s
# 718:	learn: 0.3230718	total: 37.4s	remaining: 8m 2s
# 719:	learn: 0.3229099	total: 37.4s	remaining: 8m 2s
# 720:	learn: 0.3227964	total: 37.5s	remaining: 8m 2s
# 721:	learn: 0.3226493	total: 37.5s	remaining: 8m 2s
# 722:	learn: 0.3225806	total: 37.6s	remaining: 8m 2s
# 723:	learn: 0.3224101	total: 37.6s	remaining: 8m 2s
# 724:	learn: 0.3222543	total: 37.7s	remaining: 8m 1s
# 725:	learn: 0.3220767	total: 37.7s	remaining: 8m 1s
# 726:	learn: 0.3219695	total: 37.8s	remaining: 8m 1s
# 727:	learn: 0.3217871	total: 37.8s	remaining: 8m 1s
# 728:	learn: 0.3217039	total: 37.9s	remaining: 8m 1s
# 729:	learn: 0.3214770	total: 37.9s	remaining: 8m 1s
# 730:	learn: 0.3213035	total: 38s	remaining: 8m 1s
# 731:	learn: 0.3211471	total: 38s	remaining: 8m 1s
# 732:	learn: 0.3210054	total: 38.1s	remaining: 8m 1s
# 733:	learn: 0.3207938	total: 38.1s	remaining: 8m 1s
# 734:	learn: 0.3206213	total: 38.2s	remaining: 8m 1s
# 735:	learn: 0.3204047	total: 38.2s	remaining: 8m 1s
# 736:	learn: 0.3202547	total: 38.3s	remaining: 8m 1s
# 737:	learn: 0.3201077	total: 38.3s	remaining: 8m 1s
# 738:	learn: 0.3199285	total: 38.4s	remaining: 8m 1s
# 739:	learn: 0.3197971	total: 38.4s	remaining: 8m 1s
# 740:	learn: 0.3196482	total: 38.5s	remaining: 8m
# 741:	learn: 0.3194859	total: 38.5s	remaining: 8m
# 742:	learn: 0.3193199	total: 38.6s	remaining: 8m
# 743:	learn: 0.3192111	total: 38.6s	remaining: 8m
# 744:	learn: 0.3190630	total: 38.7s	remaining: 8m
# 745:	learn: 0.3189146	total: 38.7s	remaining: 8m
# 746:	learn: 0.3187800	total: 38.8s	remaining: 8m
# 747:	learn: 0.3185894	total: 38.8s	remaining: 8m
# 748:	learn: 0.3184530	total: 38.9s	remaining: 8m
# 749:	learn: 0.3183480	total: 38.9s	remaining: 8m
# 750:	learn: 0.3182320	total: 39s	remaining: 8m
# 751:	learn: 0.3181077	total: 39s	remaining: 7m 59s
# 752:	learn: 0.3179705	total: 39.1s	remaining: 7m 59s
# 753:	learn: 0.3178609	total: 39.1s	remaining: 7m 59s
# 754:	learn: 0.3177018	total: 39.2s	remaining: 7m 59s
# 755:	learn: 0.3176230	total: 39.2s	remaining: 7m 59s
# 756:	learn: 0.3173730	total: 39.3s	remaining: 7m 59s
# 757:	learn: 0.3172225	total: 39.3s	remaining: 7m 59s
# 758:	learn: 0.3170643	total: 39.4s	remaining: 7m 59s
# 759:	learn: 0.3169387	total: 39.4s	remaining: 7m 59s
# 760:	learn: 0.3168273	total: 39.5s	remaining: 7m 59s
# 761:	learn: 0.3166955	total: 39.5s	remaining: 7m 59s
# 762:	learn: 0.3165890	total: 39.6s	remaining: 7m 58s
# 763:	learn: 0.3164380	total: 39.6s	remaining: 7m 58s
# 764:	learn: 0.3162699	total: 39.7s	remaining: 7m 58s
# 765:	learn: 0.3162087	total: 39.7s	remaining: 7m 58s
# 766:	learn: 0.3160465	total: 39.8s	remaining: 7m 58s
# 767:	learn: 0.3158910	total: 39.8s	remaining: 7m 58s
# 768:	learn: 0.3157946	total: 39.9s	remaining: 7m 58s
# 769:	learn: 0.3156626	total: 39.9s	remaining: 7m 58s
# 770:	learn: 0.3154378	total: 40s	remaining: 7m 58s
# 771:	learn: 0.3152574	total: 40s	remaining: 7m 58s
# 772:	learn: 0.3150805	total: 40.1s	remaining: 7m 58s
# 773:	learn: 0.3149428	total: 40.1s	remaining: 7m 58s
# 774:	learn: 0.3147958	total: 40.2s	remaining: 7m 58s
# 775:	learn: 0.3146376	total: 40.2s	remaining: 7m 58s
# 776:	learn: 0.3145178	total: 40.3s	remaining: 7m 58s
# 777:	learn: 0.3143585	total: 40.3s	remaining: 7m 58s
# 778:	learn: 0.3142194	total: 40.4s	remaining: 7m 57s
# 779:	learn: 0.3140621	total: 40.4s	remaining: 7m 57s
# 780:	learn: 0.3139583	total: 40.5s	remaining: 7m 57s
# 781:	learn: 0.3137215	total: 40.5s	remaining: 7m 57s
# 782:	learn: 0.3135972	total: 40.6s	remaining: 7m 57s
# 783:	learn: 0.3134034	total: 40.6s	remaining: 7m 57s
# 784:	learn: 0.3132721	total: 40.7s	remaining: 7m 57s
# 785:	learn: 0.3130448	total: 40.7s	remaining: 7m 57s
# 786:	learn: 0.3128816	total: 40.8s	remaining: 7m 57s
# 787:	learn: 0.3127144	total: 40.8s	remaining: 7m 57s
# 788:	learn: 0.3125229	total: 40.9s	remaining: 7m 57s
# 789:	learn: 0.3123775	total: 40.9s	remaining: 7m 57s
# 790:	learn: 0.3122043	total: 41s	remaining: 7m 57s
# 791:	learn: 0.3120614	total: 41s	remaining: 7m 57s
# 792:	learn: 0.3119077	total: 41.1s	remaining: 7m 56s
# 793:	learn: 0.3117521	total: 41.1s	remaining: 7m 56s
# 794:	learn: 0.3116253	total: 41.2s	remaining: 7m 56s
# 795:	learn: 0.3114322	total: 41.2s	remaining: 7m 56s
# 796:	learn: 0.3112428	total: 41.3s	remaining: 7m 56s
# 797:	learn: 0.3110793	total: 41.3s	remaining: 7m 56s
# 798:	learn: 0.3109443	total: 41.4s	remaining: 7m 56s
# 799:	learn: 0.3108138	total: 41.5s	remaining: 7m 56s
# 800:	learn: 0.3106892	total: 41.5s	remaining: 7m 56s
# 801:	learn: 0.3105170	total: 41.6s	remaining: 7m 56s
# 802:	learn: 0.3103793	total: 41.6s	remaining: 7m 56s
# 803:	learn: 0.3102346	total: 41.7s	remaining: 7m 56s
# 804:	learn: 0.3100893	total: 41.7s	remaining: 7m 56s
# 805:	learn: 0.3099325	total: 41.8s	remaining: 7m 56s
# 806:	learn: 0.3097694	total: 41.8s	remaining: 7m 56s
# 807:	learn: 0.3094932	total: 41.9s	remaining: 7m 56s
# 808:	learn: 0.3093264	total: 42s	remaining: 7m 56s
# 809:	learn: 0.3091936	total: 42s	remaining: 7m 56s
# 810:	learn: 0.3090290	total: 42.1s	remaining: 7m 56s
# 811:	learn: 0.3089132	total: 42.1s	remaining: 7m 56s
# 812:	learn: 0.3087465	total: 42.2s	remaining: 7m 56s
# 813:	learn: 0.3086121	total: 42.2s	remaining: 7m 56s
# 814:	learn: 0.3084474	total: 42.3s	remaining: 7m 56s
# 815:	learn: 0.3083228	total: 42.3s	remaining: 7m 56s
# 816:	learn: 0.3081211	total: 42.4s	remaining: 7m 56s
# 817:	learn: 0.3079464	total: 42.4s	remaining: 7m 56s
# 818:	learn: 0.3078060	total: 42.5s	remaining: 7m 56s
# 819:	learn: 0.3076650	total: 42.5s	remaining: 7m 56s
# 820:	learn: 0.3075552	total: 42.6s	remaining: 7m 55s
# 821:	learn: 0.3073797	total: 42.6s	remaining: 7m 55s
# 822:	learn: 0.3072452	total: 42.7s	remaining: 7m 55s
# 823:	learn: 0.3071265	total: 42.7s	remaining: 7m 55s
# 824:	learn: 0.3070154	total: 42.8s	remaining: 7m 55s
# 825:	learn: 0.3069189	total: 42.8s	remaining: 7m 55s
# 826:	learn: 0.3067335	total: 42.9s	remaining: 7m 55s
# 827:	learn: 0.3066121	total: 42.9s	remaining: 7m 55s
# 828:	learn: 0.3064752	total: 43s	remaining: 7m 55s
# 829:	learn: 0.3063505	total: 43s	remaining: 7m 55s
# 830:	learn: 0.3061662	total: 43.1s	remaining: 7m 55s
# 831:	learn: 0.3060653	total: 43.1s	remaining: 7m 55s
# 832:	learn: 0.3059654	total: 43.2s	remaining: 7m 55s
# 833:	learn: 0.3057736	total: 43.2s	remaining: 7m 54s
# 834:	learn: 0.3056862	total: 43.3s	remaining: 7m 54s
# 835:	learn: 0.3055841	total: 43.3s	remaining: 7m 54s
# 836:	learn: 0.3054223	total: 43.4s	remaining: 7m 54s
# 837:	learn: 0.3053216	total: 43.4s	remaining: 7m 54s
# 838:	learn: 0.3050847	total: 43.5s	remaining: 7m 54s
# 839:	learn: 0.3049284	total: 43.5s	remaining: 7m 54s
# 840:	learn: 0.3047720	total: 43.6s	remaining: 7m 54s
# 841:	learn: 0.3046589	total: 43.6s	remaining: 7m 54s
# 842:	learn: 0.3044432	total: 43.7s	remaining: 7m 54s
# 843:	learn: 0.3042992	total: 43.7s	remaining: 7m 54s
# 844:	learn: 0.3041391	total: 43.8s	remaining: 7m 54s
# 845:	learn: 0.3039728	total: 43.8s	remaining: 7m 54s
# 846:	learn: 0.3038485	total: 43.9s	remaining: 7m 54s
# 847:	learn: 0.3037240	total: 43.9s	remaining: 7m 54s
# 848:	learn: 0.3036203	total: 44s	remaining: 7m 54s
# 849:	learn: 0.3035029	total: 44s	remaining: 7m 53s
# 850:	learn: 0.3033551	total: 44.1s	remaining: 7m 54s
# 851:	learn: 0.3032410	total: 44.2s	remaining: 7m 54s
# 852:	learn: 0.3030836	total: 44.3s	remaining: 7m 54s
# 853:	learn: 0.3029283	total: 44.3s	remaining: 7m 54s
# 854:	learn: 0.3028045	total: 44.4s	remaining: 7m 54s
# 855:	learn: 0.3026441	total: 44.4s	remaining: 7m 54s
# 856:	learn: 0.3024328	total: 44.5s	remaining: 7m 54s
# 857:	learn: 0.3022344	total: 44.5s	remaining: 7m 54s
# 858:	learn: 0.3021419	total: 44.6s	remaining: 7m 54s
# 859:	learn: 0.3019859	total: 44.7s	remaining: 7m 54s
# 860:	learn: 0.3018428	total: 44.7s	remaining: 7m 54s
# 861:	learn: 0.3016866	total: 44.8s	remaining: 7m 54s
# 862:	learn: 0.3015195	total: 44.8s	remaining: 7m 54s
# 863:	learn: 0.3013883	total: 44.9s	remaining: 7m 54s
# 864:	learn: 0.3011482	total: 44.9s	remaining: 7m 54s
# 865:	learn: 0.3010176	total: 45s	remaining: 7m 54s
# 866:	learn: 0.3008275	total: 45s	remaining: 7m 54s
# 867:	learn: 0.3006490	total: 45.1s	remaining: 7m 54s
# 868:	learn: 0.3004246	total: 45.1s	remaining: 7m 54s
# 869:	learn: 0.3002444	total: 45.2s	remaining: 7m 54s
# 870:	learn: 0.3001151	total: 45.2s	remaining: 7m 54s
# 871:	learn: 0.2999168	total: 45.3s	remaining: 7m 53s
# 872:	learn: 0.2998178	total: 45.3s	remaining: 7m 53s
# 873:	learn: 0.2997116	total: 45.4s	remaining: 7m 53s
# 874:	learn: 0.2995699	total: 45.4s	remaining: 7m 53s
# 875:	learn: 0.2994254	total: 45.5s	remaining: 7m 53s
# 876:	learn: 0.2993336	total: 45.5s	remaining: 7m 53s
# 877:	learn: 0.2991480	total: 45.6s	remaining: 7m 53s
# 878:	learn: 0.2990705	total: 45.6s	remaining: 7m 53s
# 879:	learn: 0.2989376	total: 45.7s	remaining: 7m 53s
# 880:	learn: 0.2987989	total: 45.7s	remaining: 7m 53s
# 881:	learn: 0.2986793	total: 45.8s	remaining: 7m 53s
# 882:	learn: 0.2985449	total: 45.8s	remaining: 7m 53s
# 883:	learn: 0.2983425	total: 45.9s	remaining: 7m 52s
# 884:	learn: 0.2981627	total: 45.9s	remaining: 7m 52s
# 885:	learn: 0.2980591	total: 46s	remaining: 7m 52s
# 886:	learn: 0.2979019	total: 46s	remaining: 7m 52s
# 887:	learn: 0.2977295	total: 46.1s	remaining: 7m 52s
# 888:	learn: 0.2975928	total: 46.1s	remaining: 7m 52s
# 889:	learn: 0.2974769	total: 46.2s	remaining: 7m 52s
# 890:	learn: 0.2973289	total: 46.3s	remaining: 7m 52s
# 891:	learn: 0.2971158	total: 46.3s	remaining: 7m 52s
# 892:	learn: 0.2970166	total: 46.4s	remaining: 7m 52s
# 893:	learn: 0.2968522	total: 46.4s	remaining: 7m 52s
# 894:	learn: 0.2966799	total: 46.5s	remaining: 7m 52s
# 895:	learn: 0.2964879	total: 46.5s	remaining: 7m 52s
# 896:	learn: 0.2963401	total: 46.6s	remaining: 7m 52s
# 897:	learn: 0.2962272	total: 46.6s	remaining: 7m 52s
# 898:	learn: 0.2960468	total: 46.7s	remaining: 7m 52s
# 899:	learn: 0.2958948	total: 46.7s	remaining: 7m 52s
# 900:	learn: 0.2957456	total: 46.8s	remaining: 7m 52s
# 901:	learn: 0.2955968	total: 46.8s	remaining: 7m 52s
# 902:	learn: 0.2954909	total: 46.9s	remaining: 7m 52s
# 903:	learn: 0.2953717	total: 46.9s	remaining: 7m 52s
# 904:	learn: 0.2952309	total: 47s	remaining: 7m 52s
# 905:	learn: 0.2950598	total: 47s	remaining: 7m 52s
# 906:	learn: 0.2949250	total: 47.1s	remaining: 7m 52s
# 907:	learn: 0.2948217	total: 47.1s	remaining: 7m 52s
# 908:	learn: 0.2945953	total: 47.2s	remaining: 7m 52s
# 909:	learn: 0.2944508	total: 47.2s	remaining: 7m 51s
# 910:	learn: 0.2943282	total: 47.3s	remaining: 7m 51s
# 911:	learn: 0.2941742	total: 47.3s	remaining: 7m 51s
# 912:	learn: 0.2941019	total: 47.4s	remaining: 7m 51s
# 913:	learn: 0.2939928	total: 47.4s	remaining: 7m 51s
# ...
# 9703:	learn: 0.0141975	total: 8m 21s	remaining: 15.3s
# 9704:	learn: 0.0141937	total: 8m 21s	remaining: 15.2s
# 9705:	learn: 0.0141920	total: 8m 21s	remaining: 15.2s
# 9706:	learn: 0.0141889	total: 8m 21s	remaining: 15.1s
# 9707:	learn: 0.0141878	total: 8m 21s	remaining: 15.1s
# 9708:	learn: 0.0141854	total: 8m 21s	remaining: 15s
# 9709:	learn: 0.0141841	total: 8m 21s	remaining: 15s
# 9710:	learn: 0.0141814	total: 8m 21s	remaining: 14.9s
# 9711:	learn: 0.0141801	total: 8m 21s	remaining: 14.9s
# 9712:	learn: 0.0141799	total: 8m 21s	remaining: 14.8s
# 9713:	learn: 0.0141772	total: 8m 21s	remaining: 14.8s
# 9714:	learn: 0.0141762	total: 8m 21s	remaining: 14.7s
# 9715:	learn: 0.0141752	total: 8m 21s	remaining: 14.7s
# 9716:	learn: 0.0141731	total: 8m 21s	remaining: 14.6s
# 9717:	learn: 0.0141672	total: 8m 21s	remaining: 14.6s
# 9718:	learn: 0.0141662	total: 8m 21s	remaining: 14.5s
# 9719:	learn: 0.0141654	total: 8m 21s	remaining: 14.5s
# 9720:	learn: 0.0141623	total: 8m 21s	remaining: 14.4s
# 9721:	learn: 0.0141585	total: 8m 21s	remaining: 14.4s
# 9722:	learn: 0.0141550	total: 8m 22s	remaining: 14.3s
# 9723:	learn: 0.0141495	total: 8m 22s	remaining: 14.3s
# 9724:	learn: 0.0141458	total: 8m 22s	remaining: 14.2s
# 9725:	learn: 0.0141440	total: 8m 22s	remaining: 14.1s
# 9726:	learn: 0.0141424	total: 8m 22s	remaining: 14.1s
# 9727:	learn: 0.0141397	total: 8m 22s	remaining: 14s
# 9728:	learn: 0.0141341	total: 8m 22s	remaining: 14s
# 9729:	learn: 0.0141323	total: 8m 22s	remaining: 13.9s
# 9730:	learn: 0.0141305	total: 8m 22s	remaining: 13.9s
# 9731:	learn: 0.0141269	total: 8m 22s	remaining: 13.8s
# 9732:	learn: 0.0141262	total: 8m 22s	remaining: 13.8s
# 9733:	learn: 0.0141246	total: 8m 22s	remaining: 13.7s
# 9734:	learn: 0.0141224	total: 8m 22s	remaining: 13.7s
# 9735:	learn: 0.0141203	total: 8m 22s	remaining: 13.6s
# 9736:	learn: 0.0141187	total: 8m 22s	remaining: 13.6s
# 9737:	learn: 0.0141180	total: 8m 22s	remaining: 13.5s
# 9738:	learn: 0.0141170	total: 8m 22s	remaining: 13.5s
# 9739:	learn: 0.0141146	total: 8m 22s	remaining: 13.4s
# 9740:	learn: 0.0141140	total: 8m 22s	remaining: 13.4s
# 9741:	learn: 0.0141121	total: 8m 22s	remaining: 13.3s
# 9742:	learn: 0.0141092	total: 8m 22s	remaining: 13.3s
# 9743:	learn: 0.0141060	total: 8m 22s	remaining: 13.2s
# 9744:	learn: 0.0141044	total: 8m 23s	remaining: 13.2s
# 9745:	learn: 0.0141033	total: 8m 23s	remaining: 13.1s
# 9746:	learn: 0.0140977	total: 8m 23s	remaining: 13.1s
# 9747:	learn: 0.0140945	total: 8m 23s	remaining: 13s
# 9748:	learn: 0.0140925	total: 8m 23s	remaining: 13s
# 9749:	learn: 0.0140886	total: 8m 23s	remaining: 12.9s
# 9750:	learn: 0.0140874	total: 8m 23s	remaining: 12.9s
# 9751:	learn: 0.0140854	total: 8m 23s	remaining: 12.8s
# 9752:	learn: 0.0140825	total: 8m 23s	remaining: 12.7s
# 9753:	learn: 0.0140783	total: 8m 23s	remaining: 12.7s
# 9754:	learn: 0.0140760	total: 8m 23s	remaining: 12.6s
# 9755:	learn: 0.0140713	total: 8m 23s	remaining: 12.6s
# 9756:	learn: 0.0140666	total: 8m 23s	remaining: 12.5s
# 9757:	learn: 0.0140660	total: 8m 23s	remaining: 12.5s
# 9758:	learn: 0.0140642	total: 8m 23s	remaining: 12.4s
# 9759:	learn: 0.0140599	total: 8m 23s	remaining: 12.4s
# 9760:	learn: 0.0140553	total: 8m 23s	remaining: 12.3s
# 9761:	learn: 0.0140540	total: 8m 23s	remaining: 12.3s
# 9762:	learn: 0.0140526	total: 8m 24s	remaining: 12.2s
# 9763:	learn: 0.0140465	total: 8m 24s	remaining: 12.2s
# 9764:	learn: 0.0140411	total: 8m 24s	remaining: 12.1s
# 9765:	learn: 0.0140381	total: 8m 24s	remaining: 12.1s
# 9766:	learn: 0.0140367	total: 8m 24s	remaining: 12s
# 9767:	learn: 0.0140340	total: 8m 24s	remaining: 12s
# 9768:	learn: 0.0140304	total: 8m 24s	remaining: 11.9s
# 9769:	learn: 0.0140301	total: 8m 24s	remaining: 11.9s
# 9770:	learn: 0.0140276	total: 8m 24s	remaining: 11.8s
# 9771:	learn: 0.0140242	total: 8m 24s	remaining: 11.8s
# 9772:	learn: 0.0140237	total: 8m 24s	remaining: 11.7s
# 9773:	learn: 0.0140223	total: 8m 24s	remaining: 11.7s
# 9774:	learn: 0.0140195	total: 8m 24s	remaining: 11.6s
# 9775:	learn: 0.0140146	total: 8m 24s	remaining: 11.6s
# 9776:	learn: 0.0140116	total: 8m 24s	remaining: 11.5s
# 9777:	learn: 0.0140102	total: 8m 24s	remaining: 11.5s
# 9778:	learn: 0.0140057	total: 8m 24s	remaining: 11.4s
# 9779:	learn: 0.0140026	total: 8m 25s	remaining: 11.4s
# 9780:	learn: 0.0140004	total: 8m 25s	remaining: 11.3s
# 9781:	learn: 0.0139989	total: 8m 25s	remaining: 11.3s
# 9782:	learn: 0.0139974	total: 8m 25s	remaining: 11.2s
# 9783:	learn: 0.0139932	total: 8m 25s	remaining: 11.2s
# 9784:	learn: 0.0139883	total: 8m 25s	remaining: 11.1s
# 9785:	learn: 0.0139837	total: 8m 25s	remaining: 11.1s
# 9786:	learn: 0.0139791	total: 8m 25s	remaining: 11s
# 9787:	learn: 0.0139732	total: 8m 25s	remaining: 10.9s
# 9788:	learn: 0.0139689	total: 8m 25s	remaining: 10.9s
# 9789:	learn: 0.0139666	total: 8m 25s	remaining: 10.8s
# 9790:	learn: 0.0139636	total: 8m 25s	remaining: 10.8s
# 9791:	learn: 0.0139611	total: 8m 25s	remaining: 10.7s
# 9792:	learn: 0.0139599	total: 8m 25s	remaining: 10.7s
# 9793:	learn: 0.0139539	total: 8m 25s	remaining: 10.6s
# 9794:	learn: 0.0139529	total: 8m 25s	remaining: 10.6s
# 9795:	learn: 0.0139518	total: 8m 25s	remaining: 10.5s
# 9796:	learn: 0.0139495	total: 8m 25s	remaining: 10.5s
# 9797:	learn: 0.0139484	total: 8m 26s	remaining: 10.4s
# 9798:	learn: 0.0139454	total: 8m 26s	remaining: 10.4s
# 9799:	learn: 0.0139395	total: 8m 26s	remaining: 10.3s
# 9800:	learn: 0.0139373	total: 8m 26s	remaining: 10.3s
# 9801:	learn: 0.0139330	total: 8m 26s	remaining: 10.2s
# 9802:	learn: 0.0139309	total: 8m 26s	remaining: 10.2s
# 9803:	learn: 0.0139299	total: 8m 26s	remaining: 10.1s
# 9804:	learn: 0.0139291	total: 8m 26s	remaining: 10.1s
# 9805:	learn: 0.0139277	total: 8m 26s	remaining: 10s
# 9806:	learn: 0.0139235	total: 8m 26s	remaining: 9.97s
# 9807:	learn: 0.0139211	total: 8m 26s	remaining: 9.92s
# 9808:	learn: 0.0139186	total: 8m 26s	remaining: 9.87s
# 9809:	learn: 0.0139166	total: 8m 26s	remaining: 9.81s
# 9810:	learn: 0.0139141	total: 8m 26s	remaining: 9.76s
# 9811:	learn: 0.0139129	total: 8m 26s	remaining: 9.71s
# 9812:	learn: 0.0139067	total: 8m 26s	remaining: 9.66s
# 9813:	learn: 0.0139048	total: 8m 26s	remaining: 9.61s
# 9814:	learn: 0.0139029	total: 8m 26s	remaining: 9.56s
# 9815:	learn: 0.0139025	total: 8m 27s	remaining: 9.5s
# 9816:	learn: 0.0139005	total: 8m 27s	remaining: 9.45s
# 9817:	learn: 0.0138945	total: 8m 27s	remaining: 9.4s
# 9818:	learn: 0.0138924	total: 8m 27s	remaining: 9.35s
# 9819:	learn: 0.0138924	total: 8m 27s	remaining: 9.3s
# 9820:	learn: 0.0138886	total: 8m 27s	remaining: 9.25s
# 9821:	learn: 0.0138852	total: 8m 27s	remaining: 9.2s
# 9822:	learn: 0.0138812	total: 8m 27s	remaining: 9.14s
# 9823:	learn: 0.0138788	total: 8m 27s	remaining: 9.09s
# 9824:	learn: 0.0138764	total: 8m 27s	remaining: 9.04s
# 9825:	learn: 0.0138744	total: 8m 27s	remaining: 8.99s
# 9826:	learn: 0.0138727	total: 8m 27s	remaining: 8.94s
# 9827:	learn: 0.0138684	total: 8m 27s	remaining: 8.89s
# 9828:	learn: 0.0138658	total: 8m 27s	remaining: 8.83s
# 9829:	learn: 0.0138646	total: 8m 27s	remaining: 8.78s
# 9830:	learn: 0.0138639	total: 8m 27s	remaining: 8.73s
# 9831:	learn: 0.0138601	total: 8m 27s	remaining: 8.68s
# 9832:	learn: 0.0138584	total: 8m 28s	remaining: 8.63s
# 9833:	learn: 0.0138561	total: 8m 28s	remaining: 8.58s
# 9834:	learn: 0.0138537	total: 8m 28s	remaining: 8.52s
# 9835:	learn: 0.0138477	total: 8m 28s	remaining: 8.47s
# 9836:	learn: 0.0138476	total: 8m 28s	remaining: 8.42s
# 9837:	learn: 0.0138408	total: 8m 28s	remaining: 8.37s
# 9838:	learn: 0.0138374	total: 8m 28s	remaining: 8.32s
# 9839:	learn: 0.0138365	total: 8m 28s	remaining: 8.27s
# 9840:	learn: 0.0138356	total: 8m 28s	remaining: 8.21s
# 9841:	learn: 0.0138294	total: 8m 28s	remaining: 8.16s
# 9842:	learn: 0.0138287	total: 8m 28s	remaining: 8.11s
# 9843:	learn: 0.0138267	total: 8m 28s	remaining: 8.06s
# 9844:	learn: 0.0138264	total: 8m 28s	remaining: 8.01s
# 9845:	learn: 0.0138257	total: 8m 28s	remaining: 7.96s
# 9846:	learn: 0.0138231	total: 8m 28s	remaining: 7.91s
# 9847:	learn: 0.0138204	total: 8m 28s	remaining: 7.85s
# 9848:	learn: 0.0138182	total: 8m 28s	remaining: 7.8s
# 9849:	learn: 0.0138127	total: 8m 28s	remaining: 7.75s
# 9850:	learn: 0.0138103	total: 8m 29s	remaining: 7.7s
# 9851:	learn: 0.0138098	total: 8m 29s	remaining: 7.65s
# 9852:	learn: 0.0138072	total: 8m 29s	remaining: 7.59s
# 9853:	learn: 0.0138020	total: 8m 29s	remaining: 7.54s
# 9854:	learn: 0.0137995	total: 8m 29s	remaining: 7.49s
# 9855:	learn: 0.0137978	total: 8m 29s	remaining: 7.44s
# 9856:	learn: 0.0137930	total: 8m 29s	remaining: 7.39s
# 9857:	learn: 0.0137903	total: 8m 29s	remaining: 7.34s
# 9858:	learn: 0.0137891	total: 8m 29s	remaining: 7.29s
# 9859:	learn: 0.0137872	total: 8m 29s	remaining: 7.23s
# 9860:	learn: 0.0137842	total: 8m 29s	remaining: 7.18s
# 9861:	learn: 0.0137786	total: 8m 29s	remaining: 7.13s
# 9862:	learn: 0.0137756	total: 8m 29s	remaining: 7.08s
# 9863:	learn: 0.0137720	total: 8m 29s	remaining: 7.03s
# 9864:	learn: 0.0137682	total: 8m 29s	remaining: 6.98s
# 9865:	learn: 0.0137675	total: 8m 29s	remaining: 6.92s
# 9866:	learn: 0.0137634	total: 8m 29s	remaining: 6.87s
# 9867:	learn: 0.0137594	total: 8m 29s	remaining: 6.82s
# 9868:	learn: 0.0137544	total: 8m 30s	remaining: 6.77s
# 9869:	learn: 0.0137505	total: 8m 30s	remaining: 6.72s
# 9870:	learn: 0.0137472	total: 8m 30s	remaining: 6.67s
# 9871:	learn: 0.0137433	total: 8m 30s	remaining: 6.61s
# 9872:	learn: 0.0137406	total: 8m 30s	remaining: 6.56s
# 9873:	learn: 0.0137373	total: 8m 30s	remaining: 6.51s
# 9874:	learn: 0.0137352	total: 8m 30s	remaining: 6.46s
# 9875:	learn: 0.0137335	total: 8m 30s	remaining: 6.41s
# 9876:	learn: 0.0137334	total: 8m 30s	remaining: 6.36s
# 9877:	learn: 0.0137326	total: 8m 30s	remaining: 6.3s
# 9878:	learn: 0.0137318	total: 8m 30s	remaining: 6.25s
# 9879:	learn: 0.0137306	total: 8m 30s	remaining: 6.2s
# 9880:	learn: 0.0137303	total: 8m 30s	remaining: 6.15s
# 9881:	learn: 0.0137249	total: 8m 30s	remaining: 6.1s
# 9882:	learn: 0.0137191	total: 8m 30s	remaining: 6.05s
# 9883:	learn: 0.0137156	total: 8m 30s	remaining: 5.99s
# 9884:	learn: 0.0137097	total: 8m 30s	remaining: 5.94s
# 9885:	learn: 0.0137082	total: 8m 30s	remaining: 5.89s
# 9886:	learn: 0.0137060	total: 8m 30s	remaining: 5.84s
# 9887:	learn: 0.0137024	total: 8m 31s	remaining: 5.79s
# 9888:	learn: 0.0136983	total: 8m 31s	remaining: 5.74s
# 9889:	learn: 0.0136966	total: 8m 31s	remaining: 5.68s
# 9890:	learn: 0.0136927	total: 8m 31s	remaining: 5.63s
# 9891:	learn: 0.0136871	total: 8m 31s	remaining: 5.58s
# 9892:	learn: 0.0136865	total: 8m 31s	remaining: 5.53s
# 9893:	learn: 0.0136861	total: 8m 31s	remaining: 5.48s
# 9894:	learn: 0.0136845	total: 8m 31s	remaining: 5.43s
# 9895:	learn: 0.0136792	total: 8m 31s	remaining: 5.38s
# 9896:	learn: 0.0136746	total: 8m 31s	remaining: 5.32s
# 9897:	learn: 0.0136736	total: 8m 31s	remaining: 5.27s
# 9898:	learn: 0.0136681	total: 8m 31s	remaining: 5.22s
# 9899:	learn: 0.0136639	total: 8m 31s	remaining: 5.17s
# 9900:	learn: 0.0136621	total: 8m 31s	remaining: 5.12s
# 9901:	learn: 0.0136610	total: 8m 31s	remaining: 5.07s
# 9902:	learn: 0.0136597	total: 8m 31s	remaining: 5.01s
# 9903:	learn: 0.0136559	total: 8m 31s	remaining: 4.96s
# 9904:	learn: 0.0136543	total: 8m 31s	remaining: 4.91s
# 9905:	learn: 0.0136541	total: 8m 32s	remaining: 4.86s
# 9906:	learn: 0.0136519	total: 8m 32s	remaining: 4.81s
# 9907:	learn: 0.0136475	total: 8m 32s	remaining: 4.75s
# 9908:	learn: 0.0136450	total: 8m 32s	remaining: 4.7s
# 9909:	learn: 0.0136413	total: 8m 32s	remaining: 4.65s
# 9910:	learn: 0.0136402	total: 8m 32s	remaining: 4.6s
# 9911:	learn: 0.0136402	total: 8m 32s	remaining: 4.55s
# 9912:	learn: 0.0136376	total: 8m 32s	remaining: 4.5s
# 9913:	learn: 0.0136357	total: 8m 32s	remaining: 4.45s
# 9914:	learn: 0.0136333	total: 8m 32s	remaining: 4.39s
# 9915:	learn: 0.0136330	total: 8m 32s	remaining: 4.34s
# 9916:	learn: 0.0136321	total: 8m 32s	remaining: 4.29s
# 9917:	learn: 0.0136272	total: 8m 32s	remaining: 4.24s
# 9918:	learn: 0.0136239	total: 8m 32s	remaining: 4.19s
# 9919:	learn: 0.0136207	total: 8m 32s	remaining: 4.13s
# 9920:	learn: 0.0136200	total: 8m 32s	remaining: 4.08s
# 9921:	learn: 0.0136175	total: 8m 32s	remaining: 4.03s
# 9922:	learn: 0.0136157	total: 8m 32s	remaining: 3.98s
# 9923:	learn: 0.0136113	total: 8m 32s	remaining: 3.93s
# 9924:	learn: 0.0136079	total: 8m 33s	remaining: 3.88s
# 9925:	learn: 0.0136030	total: 8m 33s	remaining: 3.83s
# 9926:	learn: 0.0136009	total: 8m 33s	remaining: 3.77s
# 9927:	learn: 0.0135967	total: 8m 33s	remaining: 3.72s
# 9928:	learn: 0.0135915	total: 8m 33s	remaining: 3.67s
# 9929:	learn: 0.0135871	total: 8m 33s	remaining: 3.62s
# 9930:	learn: 0.0135865	total: 8m 33s	remaining: 3.57s
# 9931:	learn: 0.0135813	total: 8m 33s	remaining: 3.52s
# 9932:	learn: 0.0135807	total: 8m 33s	remaining: 3.46s
# 9933:	learn: 0.0135759	total: 8m 33s	remaining: 3.41s
# 9934:	learn: 0.0135751	total: 8m 33s	remaining: 3.36s
# 9935:	learn: 0.0135728	total: 8m 33s	remaining: 3.31s
# 9936:	learn: 0.0135691	total: 8m 33s	remaining: 3.26s
# 9937:	learn: 0.0135643	total: 8m 33s	remaining: 3.21s
# 9938:	learn: 0.0135623	total: 8m 33s	remaining: 3.15s
# 9939:	learn: 0.0135611	total: 8m 33s	remaining: 3.1s
# 9940:	learn: 0.0135580	total: 8m 33s	remaining: 3.05s
# 9941:	learn: 0.0135570	total: 8m 34s	remaining: 3s
# 9942:	learn: 0.0135553	total: 8m 34s	remaining: 2.95s
# 9943:	learn: 0.0135541	total: 8m 34s	remaining: 2.9s
# 9944:	learn: 0.0135505	total: 8m 34s	remaining: 2.84s
# 9945:	learn: 0.0135494	total: 8m 34s	remaining: 2.79s
# 9946:	learn: 0.0135472	total: 8m 34s	remaining: 2.74s
# 9947:	learn: 0.0135440	total: 8m 34s	remaining: 2.69s
# 9948:	learn: 0.0135384	total: 8m 34s	remaining: 2.64s
# 9949:	learn: 0.0135375	total: 8m 34s	remaining: 2.58s
# 9950:	learn: 0.0135355	total: 8m 34s	remaining: 2.53s
# 9951:	learn: 0.0135316	total: 8m 34s	remaining: 2.48s
# 9952:	learn: 0.0135293	total: 8m 34s	remaining: 2.43s
# 9953:	learn: 0.0135276	total: 8m 34s	remaining: 2.38s
# 9954:	learn: 0.0135252	total: 8m 34s	remaining: 2.33s
# 9955:	learn: 0.0135211	total: 8m 34s	remaining: 2.27s
# 9956:	learn: 0.0135200	total: 8m 34s	remaining: 2.22s
# 9957:	learn: 0.0135160	total: 8m 34s	remaining: 2.17s
# 9958:	learn: 0.0135153	total: 8m 34s	remaining: 2.12s
# 9959:	learn: 0.0135145	total: 8m 35s	remaining: 2.07s
# 9960:	learn: 0.0135137	total: 8m 35s	remaining: 2.02s
# 9961:	learn: 0.0135100	total: 8m 35s	remaining: 1.96s
# 9962:	learn: 0.0135092	total: 8m 35s	remaining: 1.91s
# 9963:	learn: 0.0135044	total: 8m 35s	remaining: 1.86s
# 9964:	learn: 0.0135023	total: 8m 35s	remaining: 1.81s
# 9965:	learn: 0.0135022	total: 8m 35s	remaining: 1.76s
# 9966:	learn: 0.0135016	total: 8m 35s	remaining: 1.71s
# 9967:	learn: 0.0135002	total: 8m 35s	remaining: 1.65s
# 9968:	learn: 0.0134985	total: 8m 35s	remaining: 1.6s
# 9969:	learn: 0.0134979	total: 8m 35s	remaining: 1.55s
# 9970:	learn: 0.0134958	total: 8m 35s	remaining: 1.5s
# 9971:	learn: 0.0134918	total: 8m 35s	remaining: 1.45s
# 9972:	learn: 0.0134904	total: 8m 35s	remaining: 1.4s
# 9973:	learn: 0.0134886	total: 8m 35s	remaining: 1.34s
# 9974:	learn: 0.0134876	total: 8m 35s	remaining: 1.29s
# 9975:	learn: 0.0134863	total: 8m 35s	remaining: 1.24s
# 9976:	learn: 0.0134838	total: 8m 35s	remaining: 1.19s
# 9977:	learn: 0.0134784	total: 8m 35s	remaining: 1.14s
# 9978:	learn: 0.0134719	total: 8m 35s	remaining: 1.08s
# 9979:	learn: 0.0134692	total: 8m 36s	remaining: 1.03s
# 9980:	learn: 0.0134692	total: 8m 36s	remaining: 982ms
# 9981:	learn: 0.0134682	total: 8m 36s	remaining: 931ms
# 9982:	learn: 0.0134665	total: 8m 36s	remaining: 879ms
# 9983:	learn: 0.0134650	total: 8m 36s	remaining: 827ms
# 9984:	learn: 0.0134638	total: 8m 36s	remaining: 776ms
# 9985:	learn: 0.0134607	total: 8m 36s	remaining: 724ms
# 9986:	learn: 0.0134568	total: 8m 36s	remaining: 672ms
# 9987:	learn: 0.0134536	total: 8m 36s	remaining: 620ms
# 9988:	learn: 0.0134508	total: 8m 36s	remaining: 569ms
# 9989:	learn: 0.0134477	total: 8m 36s	remaining: 517ms
# 9990:	learn: 0.0134446	total: 8m 36s	remaining: 465ms
# 9991:	learn: 0.0134407	total: 8m 36s	remaining: 414ms
# 9992:	learn: 0.0134395	total: 8m 36s	remaining: 362ms
# 9993:	learn: 0.0134386	total: 8m 36s	remaining: 310ms
# 9994:	learn: 0.0134372	total: 8m 36s	remaining: 259ms
# 9995:	learn: 0.0134350	total: 8m 36s	remaining: 207ms
# 9996:	learn: 0.0134349	total: 8m 36s	remaining: 155ms
# 9997:	learn: 0.0134339	total: 8m 36s	remaining: 103ms
# 9998:	learn: 0.0134338	total: 8m 36s	remaining: 51.7ms
# 9999:	learn: 0.0134309	total: 8m 37s	remaining: 0us

# %%
# Predictions
predictions_3 = model_cat.predict(X_test)
print ("The Accuracy of the model is : ", accuracy_score(y_test, predictions_3), '\n')
print ("The confusion Matrix is \n")
print (confusion_matrix(y_test, predictions_3), '\n')

print (classification_report(y_test, predictions_3))
# Out:
# The Accuracy of the model is :  0.8828416015959851
#
# The confusion Matrix is
#
# [[14935  4410]
#  [ 3107 41709]]
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.77      0.80     19345
#            1       0.90      0.93      0.92     44816
#
#     accuracy                           0.88     64161
#    macro avg       0.87      0.85      0.86     64161
# weighted avg       0.88      0.88      0.88     64161
